# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import tensorflow as tf

from torch.autograd import Variable
from torchvision.models import resnet18

from tensorflow import keras
from keras.preprocessing import image

import PIL
import torch
import torchvision

import matplotlib.pyplot as plt
from sklearn import svm, datasets, metrics

torch.manual_seed(777)

# %%
# !pip install tensorboardcolab
from tensorboardcolab import TensorBoardColab
tb = TensorBoardColab()
# Out:
# Collecting tensorboardcolab
#   Downloading tensorboardcolab-0.0.22.tar.gz (2.5 kB)
# Building wheels for collected packages: tensorboardcolab
#   Building wheel for tensorboardcolab (setup.py) ... done
#   Created wheel for tensorboardcolab: filename=tensorboardcolab-0.0.22-py3-none-any.whl size=3859 sha256=596087ee165b71083dc76fa2f0c2859895299b4f53666cf8bbe6dd59fbba0e33
#   Stored in directory: /home/jun/.cache/pip/wheels/e5/6b/92/99a181b543b45a45df4346bcdf01aac1f882fe447c63302878
# Successfully built tensorboardcolab
# Installing collected packages: tensorboardcolab
# Successfully installed tensorboardcolab-0.0.22
# Wait for 8 seconds...
# Initialization failed, retry again (1)
#
#
# Wait for 8 seconds...
# Initialization failed, retry again (2)
#
#
# Wait for 8 seconds...
# Initialization failed, retry again (3)
#
#
# Wait for 8 seconds...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3d08d08f786a> in <module>
#       1 get_ipython().system('pip install tensorboardcolab')
#       2 from tensorboardcolab import TensorBoardColab
# ----> 3 tb = TensorBoardColab()
#
# ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/tensorboardcolab/core.py in __init__(self, port, graph_path, startup_waiting_time)
#      25             time.sleep(sleep_time)
#      26             get_ipython().system_raw('ngrok http %d &' % port)
# ---> 27             time.sleep(sleep_time)
#      28             try:
#      29                 tensorboard_link = get_ipython().getoutput(
#
# KeyboardInterrupt:

# %%
class NetVLAD(nn.Module):
    """NetVLAD layer implementation"""

    def __init__(self, num_clusters=6, dim=128, alpha=100.0,
                 normalize_input=True):
        """
        Args:
            num_clusters : int
                The number of clusters
            dim : int
                Dimension of descriptors
            alpha : float
                Parameter of initialization. Larger value is harder assignment.
            normalize_input : bool
                If true, descriptor-wise L2 normalization is applied to input.
        """
        super(NetVLAD, self).__init__()
        self.num_clusters = num_clusters
        self.dim = dim
        self.alpha = alpha
        self.normalize_input = normalize_input
        self.conv = nn.Conv2d(dim, num_clusters, kernel_size=(1, 1), bias=True)
        self.centroids = nn.Parameter(torch.rand(num_clusters, dim))
        self._init_params()

    def _init_params(self):
        self.conv.weight = nn.Parameter(
            (2.0 * self.alpha * self.centroids).unsqueeze(-1).unsqueeze(-1)
        )
        self.conv.bias = nn.Parameter(
            - self.alpha * self.centroids.norm(dim=1)
        )

    def forward(self, x):
        N, C = x.shape[:2]

        if self.normalize_input:
            x = F.normalize(x, p=2, dim=1)  # across descriptor dim

        # soft-assignment
        soft_assign = self.conv(x).view(N, self.num_clusters, -1)
        soft_assign = F.softmax(soft_assign, dim=1)

        x_flatten = x.view(N, C, -1)
        
        # calculate residuals to each clusters
        residual = x_flatten.expand(self.num_clusters, -1, -1, -1).permute(1, 0, 2, 3) - \
            self.centroids.expand(x_flatten.size(-1), -1, -1).permute(1, 2, 0).unsqueeze(0)
        residual *= soft_assign.unsqueeze(2)
        vlad = residual.sum(dim=-1)

        vlad = F.normalize(vlad, p=2, dim=2)  # intra-normalization
        vlad = vlad.view(x.size(0), -1)  # flatten
        vlad = F.normalize(vlad, p=2, dim=1)  # L2 normalize

        return vlad

# %%
class EmbedNet(nn.Module):
    def __init__(self, base_model, net_vlad):
        super(EmbedNet, self).__init__()
        self.base_model = base_model
        self.net_vlad = net_vlad

    def forward(self, x):
        x = self.base_model(x)
        embedded_x = self.net_vlad(x)
        return embedded_x
      
class TripletNet(nn.Module):
    def __init__(self, embed_net):
        super(TripletNet, self).__init__()
        self.embed_net = embed_net

    def forward(self, a, p, n):
        embedded_a = self.embed_net(a)
        embedded_p = self.embed_net(p)
        embedded_n = self.embed_net(n)
        return embedded_a, embedded_p, embedded_n

    def feature_extract(self, x):
        return self.embed_net(x)

# %%
class HardTripletLoss(nn.Module):
    """Hard/Hardest Triplet Loss
    (pytorch implementation of https://omoindrot.github.io/triplet-loss)
    For each anchor, we get the hardest positive and hardest negative to form a triplet.
    """
    def __init__(self, margin=0.1, hardest=False, squared=False):
        """
        Args:
            margin: margin for triplet loss
            hardest: If true, loss is considered only hardest triplets.
            squared: If true, output is the pairwise squared euclidean distance matrix.
                If false, output is the pairwise euclidean distance matrix.
        """
        super(HardTripletLoss, self).__init__()
        self.margin = margin
        self.hardest = hardest
        self.squared = squared

    def forward(self, embeddings, labels):
        """
        Args:
            labels: labels of the batch, of size (batch_size,)
            embeddings: tensor of shape (batch_size, embed_dim)
        Returns:
            triplet_loss: scalar tensor containing the triplet loss
        """
        pairwise_dist = _pairwise_distance(embeddings, squared=self.squared)

        if self.hardest:
            # Get the hardest positive pairs
            mask_anchor_positive = _get_anchor_positive_triplet_mask(labels).float()
            valid_positive_dist = pairwise_dist * mask_anchor_positive
            hardest_positive_dist, _ = torch.max(valid_positive_dist, dim=1, keepdim=True)

            # Get the hardest negative pairs
            mask_anchor_negative = _get_anchor_negative_triplet_mask(labels).float()
            max_anchor_negative_dist, _ = torch.max(pairwise_dist, dim=1, keepdim=True)
            anchor_negative_dist = pairwise_dist + max_anchor_negative_dist * (
                    1.0 - mask_anchor_negative)
            hardest_negative_dist, _ = torch.min(anchor_negative_dist, dim=1, keepdim=True)

            # Combine biggest d(a, p) and smallest d(a, n) into final triplet loss
            triplet_loss = F.relu(hardest_positive_dist - hardest_negative_dist + 0.1)
            triplet_loss = torch.mean(triplet_loss)
        else:
            anc_pos_dist = pairwise_dist.unsqueeze(dim=2)
            anc_neg_dist = pairwise_dist.unsqueeze(dim=1)

            # Compute a 3D tensor of size (batch_size, batch_size, batch_size)
            # triplet_loss[i, j, k] will contain the triplet loss of anc=i, pos=j, neg=k
            # Uses broadcasting where the 1st argument has shape (batch_size, batch_size, 1)
            # and the 2nd (batch_size, 1, batch_size)
            loss = anc_pos_dist - anc_neg_dist + self.margin

            mask = _get_triplet_mask(labels).float()
            triplet_loss = loss * mask

            # Remove negative losses (i.e. the easy triplets)
            triplet_loss = F.relu(triplet_loss)

            # Count number of hard triplets (where triplet_loss > 0)
            hard_triplets = torch.gt(triplet_loss, 1e-16).float()
            num_hard_triplets = torch.sum(hard_triplets)

            triplet_loss = torch.sum(triplet_loss) / (num_hard_triplets + 1e-16)

        return triplet_loss


def _pairwise_distance(x, squared=False, eps=1e-16):
    # Compute the 2D matrix of distances between all the embeddings.

    cor_mat = torch.matmul(x, x.t())
    norm_mat = cor_mat.diag()
    distances = norm_mat.unsqueeze(1) - 2 * cor_mat + norm_mat.unsqueeze(0)
    distances = F.relu(distances)

    if not squared:
        mask = torch.eq(distances, 0.0).float()
        distances = distances + mask * eps
        distances = torch.sqrt(distances)
        distances = distances * (1.0 - mask)

    return distances


def _get_anchor_positive_triplet_mask(labels):
    # Return a 2D mask where mask[a, p] is True iff a and p are distinct and have same label.

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    indices_not_equal = torch.eye(labels.shape[0]).to(device).byte() ^ 1

    # Check if labels[i] == labels[j]
    labels_equal = torch.unsqueeze(labels, 0) == torch.unsqueeze(labels, 1)

    mask = indices_not_equal * labels_equal

    return mask


def _get_anchor_negative_triplet_mask(labels):
    # Return a 2D mask where mask[a, n] is True iff a and n have distinct labels.

    # Check if labels[i] != labels[k]
    labels_equal = torch.unsqueeze(labels, 0) == torch.unsqueeze(labels, 1)
    mask = labels_equal ^ 1

    return mask


def _get_triplet_mask(labels):
    """Return a 3D mask where mask[a, p, n] is True iff the triplet (a, p, n) is valid.
    A triplet (i, j, k) is valid if:
        - i, j, k are distinct
        - labels[i] == labels[j] and labels[i] != labels[k]
    """
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Check that i, j and k are distinct
    indices_not_same = torch.eye(labels.shape[0]).to(device).byte() ^ 1
    i_not_equal_j = torch.unsqueeze(indices_not_same, 2)
    i_not_equal_k = torch.unsqueeze(indices_not_same, 1)
    j_not_equal_k = torch.unsqueeze(indices_not_same, 0)
    distinct_indices = i_not_equal_j * i_not_equal_k * j_not_equal_k

    # Check if labels[i] == labels[j] and labels[i] != labels[k]
    label_equal = torch.eq(torch.unsqueeze(labels, 0), torch.unsqueeze(labels, 1))
    i_equal_j = torch.unsqueeze(label_equal, 2)
    i_equal_k = torch.unsqueeze(label_equal, 1)
    valid_labels = i_equal_j * (~i_equal_k)

    mask = distinct_indices * valid_labels   # Combine the two masks

    return mask

# %%
# Discard layers at the end of base network
encoder = resnet18(pretrained=True)
base_model = nn.Sequential(
    encoder.conv1,
    encoder.bn1,
    encoder.relu,
    encoder.maxpool,
    encoder.layer1,
    encoder.layer2,
    encoder.layer3,
    encoder.layer4,
)
dim = list(base_model.parameters())[-1].shape[0]  # last channels (512)

# Define model for embedding
net_vlad = NetVLAD(num_clusters=6, dim=dim, alpha=1.0)
model = EmbedNet(base_model, net_vlad).cuda()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /home/jun/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100.0%

# %%
# Define loss
criterion = HardTripletLoss(margin=0.1).cuda()
epochs = 50
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((128,128)),               
    torchvision.transforms.ToTensor()
    
])

bef_train_imagenet_data = torchvision.datasets.ImageFolder('/home/jun/Data/Sejong/train', transform=transforms)
bef_train_data_loader = torch.utils.data.DataLoader(bef_train_imagenet_data,
                                          batch_size=776,
                                          shuffle=False,
                                          num_workers=0)

# %%
for bef_train_image,bef_train_label in bef_train_data_loader :
  bef_train_image = bef_train_image
  bef_train_label = bef_train_label

# %%
train_imagenet_data = torchvision.datasets.ImageFolder('/home/jun/Data/Sejong/train', transform=transforms)
train_data_loader = torch.utils.data.DataLoader(train_imagenet_data,
                                          batch_size=8,
                                          shuffle=True,
                                          num_workers=0)
test_imagenet_data = torchvision.datasets.ImageFolder('/home/jun/Data/Sejong/test', transform=transforms)
test_data_loader = torch.utils.data.DataLoader(test_imagenet_data,
                                          shuffle=False,
                                          batch_size=100,
                                          num_workers=0)

# %%
globaliter = 0

for epoch in range(epochs):
  for batch_idx, (train_image,train_label) in enumerate(train_data_loader) :
    output_train = model(train_image.cuda())
    triplet_loss = criterion(output_train, train_label.cuda())
    optimizer.zero_grad()
    triplet_loss.backward(retain_graph=True)
    optimizer.step()
    # This is where I'm recording to Tensorboard
    # tb.save_value('Train Loss', 'train_loss', globaliter, triplet_loss.item())
    print('epoch : {}, globaliter : {}, batch_idx  : {}, triplet_loss : {}'.format(epoch,globaliter,batch_idx,triplet_loss.item()))
    globaliter += 1
  model_save_name = 'model_{:02d}.pt'.format(epoch)
  path = F"./{model_save_name}" 
  torch.save(model.state_dict(), path)
# Out:
# epoch : 0, globaliter : 0, batch_idx  : 0, triplet_loss : 0.09533710032701492
# epoch : 0, globaliter : 1, batch_idx  : 1, triplet_loss : 0.0972115695476532
# epoch : 0, globaliter : 2, batch_idx  : 2, triplet_loss : 0.09873875230550766
# epoch : 0, globaliter : 3, batch_idx  : 3, triplet_loss : 0.09449876844882965
# epoch : 0, globaliter : 4, batch_idx  : 4, triplet_loss : 0.09846276789903641
# epoch : 0, globaliter : 5, batch_idx  : 5, triplet_loss : 0.09891442954540253
# epoch : 0, globaliter : 6, batch_idx  : 6, triplet_loss : 0.10038081556558609
# epoch : 0, globaliter : 7, batch_idx  : 7, triplet_loss : 0.09571786224842072
# epoch : 0, globaliter : 8, batch_idx  : 8, triplet_loss : 0.09475719183683395
# epoch : 0, globaliter : 9, batch_idx  : 9, triplet_loss : 0.09690630435943604
# epoch : 0, globaliter : 10, batch_idx  : 10, triplet_loss : 0.09490952640771866
# epoch : 0, globaliter : 11, batch_idx  : 11, triplet_loss : 0.09558792412281036
# epoch : 0, globaliter : 12, batch_idx  : 12, triplet_loss : 0.08861563354730606
# epoch : 0, globaliter : 13, batch_idx  : 13, triplet_loss : 0.09923722594976425
# epoch : 0, globaliter : 14, batch_idx  : 14, triplet_loss : 0.08509118109941483
# epoch : 0, globaliter : 15, batch_idx  : 15, triplet_loss : 0.0964619591832161
# epoch : 0, globaliter : 16, batch_idx  : 16, triplet_loss : 0.09406033158302307
# epoch : 0, globaliter : 17, batch_idx  : 17, triplet_loss : 0.0957404375076294
# epoch : 0, globaliter : 18, batch_idx  : 18, triplet_loss : 0.09970476478338242
# epoch : 0, globaliter : 19, batch_idx  : 19, triplet_loss : 0.09786505997180939
# epoch : 0, globaliter : 20, batch_idx  : 20, triplet_loss : 0.09090351313352585
# epoch : 0, globaliter : 21, batch_idx  : 21, triplet_loss : 0.09814481437206268
# epoch : 0, globaliter : 22, batch_idx  : 22, triplet_loss : 0.09955760091543198
# epoch : 0, globaliter : 23, batch_idx  : 23, triplet_loss : 0.09804966300725937
# epoch : 0, globaliter : 24, batch_idx  : 24, triplet_loss : 0.09764865040779114
# epoch : 0, globaliter : 25, batch_idx  : 25, triplet_loss : 0.09422197937965393
# epoch : 0, globaliter : 26, batch_idx  : 26, triplet_loss : 0.08767828345298767
# epoch : 0, globaliter : 27, batch_idx  : 27, triplet_loss : 0.08219407498836517
# epoch : 0, globaliter : 28, batch_idx  : 28, triplet_loss : 0.09929847717285156
# epoch : 0, globaliter : 29, batch_idx  : 29, triplet_loss : 0.09597461670637131
# epoch : 0, globaliter : 30, batch_idx  : 30, triplet_loss : 0.09897788614034653
# epoch : 0, globaliter : 31, batch_idx  : 31, triplet_loss : 0.08950057625770569
# epoch : 0, globaliter : 32, batch_idx  : 32, triplet_loss : 0.08193490654230118
# epoch : 0, globaliter : 33, batch_idx  : 33, triplet_loss : 0.09768790006637573
# epoch : 0, globaliter : 34, batch_idx  : 34, triplet_loss : 0.09502049535512924
# epoch : 0, globaliter : 35, batch_idx  : 35, triplet_loss : 0.09921398013830185
# epoch : 0, globaliter : 36, batch_idx  : 36, triplet_loss : 0.0964544415473938
# epoch : 0, globaliter : 37, batch_idx  : 37, triplet_loss : 0.08705354481935501
# epoch : 0, globaliter : 38, batch_idx  : 38, triplet_loss : 0.09783899039030075
# epoch : 0, globaliter : 39, batch_idx  : 39, triplet_loss : 0.09338723868131638
# epoch : 0, globaliter : 40, batch_idx  : 40, triplet_loss : 0.09536582976579666
# epoch : 0, globaliter : 41, batch_idx  : 41, triplet_loss : 0.09731552004814148
# epoch : 0, globaliter : 42, batch_idx  : 42, triplet_loss : 0.09891871362924576
# epoch : 0, globaliter : 43, batch_idx  : 43, triplet_loss : 0.09688996523618698
# epoch : 0, globaliter : 44, batch_idx  : 44, triplet_loss : 0.09445121139287949
# epoch : 0, globaliter : 45, batch_idx  : 45, triplet_loss : 0.09057929366827011
# epoch : 0, globaliter : 46, batch_idx  : 46, triplet_loss : 0.09667758643627167
# epoch : 0, globaliter : 47, batch_idx  : 47, triplet_loss : 0.09518030285835266
# epoch : 0, globaliter : 48, batch_idx  : 48, triplet_loss : 0.09685423225164413
# epoch : 0, globaliter : 49, batch_idx  : 49, triplet_loss : 0.09672317653894424
# epoch : 0, globaliter : 50, batch_idx  : 50, triplet_loss : 0.09659526497125626
# epoch : 0, globaliter : 51, batch_idx  : 51, triplet_loss : 0.10034585744142532
# epoch : 0, globaliter : 52, batch_idx  : 52, triplet_loss : 0.08651501685380936
# epoch : 0, globaliter : 53, batch_idx  : 53, triplet_loss : 0.09658536314964294
# epoch : 0, globaliter : 54, batch_idx  : 54, triplet_loss : 0.09600812196731567
# epoch : 0, globaliter : 55, batch_idx  : 55, triplet_loss : 0.09323573857545853
# epoch : 0, globaliter : 56, batch_idx  : 56, triplet_loss : 0.10024865716695786
# epoch : 0, globaliter : 57, batch_idx  : 57, triplet_loss : 0.09484509378671646
# epoch : 0, globaliter : 58, batch_idx  : 58, triplet_loss : 0.09791557490825653
# epoch : 0, globaliter : 59, batch_idx  : 59, triplet_loss : 0.09521488100290298
# epoch : 0, globaliter : 60, batch_idx  : 60, triplet_loss : 0.09624403715133667
# epoch : 0, globaliter : 61, batch_idx  : 61, triplet_loss : 0.09552285075187683
# epoch : 0, globaliter : 62, batch_idx  : 62, triplet_loss : 0.09503743052482605
# epoch : 0, globaliter : 63, batch_idx  : 63, triplet_loss : 0.09285888075828552
# epoch : 0, globaliter : 64, batch_idx  : 64, triplet_loss : 0.09192097187042236
# epoch : 0, globaliter : 65, batch_idx  : 65, triplet_loss : 0.09158781170845032
# epoch : 0, globaliter : 66, batch_idx  : 66, triplet_loss : 0.09433674812316895
# epoch : 0, globaliter : 67, batch_idx  : 67, triplet_loss : 0.08923227339982986
# epoch : 0, globaliter : 68, batch_idx  : 68, triplet_loss : 0.09341948479413986
# epoch : 0, globaliter : 69, batch_idx  : 69, triplet_loss : 0.09687521308660507
# epoch : 0, globaliter : 70, batch_idx  : 70, triplet_loss : 0.07943472266197205
# epoch : 0, globaliter : 71, batch_idx  : 71, triplet_loss : 0.09659207612276077
# epoch : 0, globaliter : 72, batch_idx  : 72, triplet_loss : 0.09563738852739334
# epoch : 0, globaliter : 73, batch_idx  : 73, triplet_loss : 0.09848018735647202
# epoch : 0, globaliter : 74, batch_idx  : 74, triplet_loss : 0.09425117820501328
# epoch : 0, globaliter : 75, batch_idx  : 75, triplet_loss : 0.09707552939653397
# epoch : 0, globaliter : 76, batch_idx  : 76, triplet_loss : 0.0940498486161232
# epoch : 0, globaliter : 77, batch_idx  : 77, triplet_loss : 0.09220921993255615
# epoch : 0, globaliter : 78, batch_idx  : 78, triplet_loss : 0.09063075482845306
# epoch : 0, globaliter : 79, batch_idx  : 79, triplet_loss : 0.093477763235569
# epoch : 0, globaliter : 80, batch_idx  : 80, triplet_loss : 0.09456895291805267
# epoch : 0, globaliter : 81, batch_idx  : 81, triplet_loss : 0.09709566086530685
# epoch : 0, globaliter : 82, batch_idx  : 82, triplet_loss : 0.09401947259902954
# epoch : 0, globaliter : 83, batch_idx  : 83, triplet_loss : 0.09720402210950851
# epoch : 0, globaliter : 84, batch_idx  : 84, triplet_loss : 0.09251514077186584
# epoch : 0, globaliter : 85, batch_idx  : 85, triplet_loss : 0.09048157185316086
# epoch : 0, globaliter : 86, batch_idx  : 86, triplet_loss : 0.09307236224412918
# epoch : 0, globaliter : 87, batch_idx  : 87, triplet_loss : 0.09496431052684784
# epoch : 0, globaliter : 88, batch_idx  : 88, triplet_loss : 0.09125354886054993
# epoch : 0, globaliter : 89, batch_idx  : 89, triplet_loss : 0.09684044122695923
# epoch : 0, globaliter : 90, batch_idx  : 90, triplet_loss : 0.09762222319841385
# epoch : 0, globaliter : 91, batch_idx  : 91, triplet_loss : 0.08978892862796783
# epoch : 0, globaliter : 92, batch_idx  : 92, triplet_loss : 0.09757884591817856
# epoch : 0, globaliter : 93, batch_idx  : 93, triplet_loss : 0.08780349791049957
# epoch : 0, globaliter : 94, batch_idx  : 94, triplet_loss : 0.09662207216024399
# epoch : 0, globaliter : 95, batch_idx  : 95, triplet_loss : 0.09451550990343094
# epoch : 0, globaliter : 96, batch_idx  : 96, triplet_loss : 0.09203111380338669
# epoch : 1, globaliter : 97, batch_idx  : 0, triplet_loss : 0.09708050638437271
# epoch : 1, globaliter : 98, batch_idx  : 1, triplet_loss : 0.09496935456991196
# epoch : 1, globaliter : 99, batch_idx  : 2, triplet_loss : 0.0970216691493988
# epoch : 1, globaliter : 100, batch_idx  : 3, triplet_loss : 0.09741798788309097
# epoch : 1, globaliter : 101, batch_idx  : 4, triplet_loss : 0.0933147668838501
# epoch : 1, globaliter : 102, batch_idx  : 5, triplet_loss : 0.09703537076711655
# epoch : 1, globaliter : 103, batch_idx  : 6, triplet_loss : 0.09826147556304932
# epoch : 1, globaliter : 104, batch_idx  : 7, triplet_loss : 0.0921471118927002
# epoch : 1, globaliter : 105, batch_idx  : 8, triplet_loss : 0.09595789760351181
# epoch : 1, globaliter : 106, batch_idx  : 9, triplet_loss : 0.09637318551540375
# epoch : 1, globaliter : 107, batch_idx  : 10, triplet_loss : 0.0942467600107193
# epoch : 1, globaliter : 108, batch_idx  : 11, triplet_loss : 0.09537360072135925
# epoch : 1, globaliter : 109, batch_idx  : 12, triplet_loss : 0.0987105593085289
# epoch : 1, globaliter : 110, batch_idx  : 13, triplet_loss : 0.09139969199895859
# epoch : 1, globaliter : 111, batch_idx  : 14, triplet_loss : 0.09793879091739655
# epoch : 1, globaliter : 112, batch_idx  : 15, triplet_loss : 0.09498963505029678
# epoch : 1, globaliter : 113, batch_idx  : 16, triplet_loss : 0.09572599828243256
# epoch : 1, globaliter : 114, batch_idx  : 17, triplet_loss : 0.0983891636133194
# epoch : 1, globaliter : 115, batch_idx  : 18, triplet_loss : 0.09297829121351242
# epoch : 1, globaliter : 116, batch_idx  : 19, triplet_loss : 0.08703278005123138
# epoch : 1, globaliter : 117, batch_idx  : 20, triplet_loss : 0.09622666984796524
# epoch : 1, globaliter : 118, batch_idx  : 21, triplet_loss : 0.09696318209171295
# epoch : 1, globaliter : 119, batch_idx  : 22, triplet_loss : 0.09498642385005951
# epoch : 1, globaliter : 120, batch_idx  : 23, triplet_loss : 0.09735937416553497
# epoch : 1, globaliter : 121, batch_idx  : 24, triplet_loss : 0.09667941182851791
# epoch : 1, globaliter : 122, batch_idx  : 25, triplet_loss : 0.09148024022579193
# epoch : 1, globaliter : 123, batch_idx  : 26, triplet_loss : 0.09453710168600082
# epoch : 1, globaliter : 124, batch_idx  : 27, triplet_loss : 0.08773456513881683
# epoch : 1, globaliter : 125, batch_idx  : 28, triplet_loss : 0.09155256301164627
# epoch : 1, globaliter : 126, batch_idx  : 29, triplet_loss : 0.0940604880452156
# epoch : 1, globaliter : 127, batch_idx  : 30, triplet_loss : 0.09629553556442261
# epoch : 1, globaliter : 128, batch_idx  : 31, triplet_loss : 0.09666518121957779
# epoch : 1, globaliter : 129, batch_idx  : 32, triplet_loss : 0.08752340078353882
# epoch : 1, globaliter : 130, batch_idx  : 33, triplet_loss : 0.090971440076828
# epoch : 1, globaliter : 131, batch_idx  : 34, triplet_loss : 0.09353058785200119
# epoch : 1, globaliter : 132, batch_idx  : 35, triplet_loss : 0.09005201607942581
# epoch : 1, globaliter : 133, batch_idx  : 36, triplet_loss : 0.09497460722923279
# epoch : 1, globaliter : 134, batch_idx  : 37, triplet_loss : 0.09228969365358353
# epoch : 1, globaliter : 135, batch_idx  : 38, triplet_loss : 0.08366049081087112
# epoch : 1, globaliter : 136, batch_idx  : 39, triplet_loss : 0.0870325043797493
# epoch : 1, globaliter : 137, batch_idx  : 40, triplet_loss : 0.09224439412355423
# epoch : 1, globaliter : 138, batch_idx  : 41, triplet_loss : 0.08921036869287491
# epoch : 1, globaliter : 139, batch_idx  : 42, triplet_loss : 0.08997399359941483
# epoch : 1, globaliter : 140, batch_idx  : 43, triplet_loss : 0.08252529054880142
# epoch : 1, globaliter : 141, batch_idx  : 44, triplet_loss : 0.09305739402770996
# epoch : 1, globaliter : 142, batch_idx  : 45, triplet_loss : 0.09518858045339584
# epoch : 1, globaliter : 143, batch_idx  : 46, triplet_loss : 0.0866822823882103
# epoch : 1, globaliter : 144, batch_idx  : 47, triplet_loss : 0.0874405950307846
# epoch : 1, globaliter : 145, batch_idx  : 48, triplet_loss : 0.08714968711137772
# epoch : 1, globaliter : 146, batch_idx  : 49, triplet_loss : 0.09319651871919632
# epoch : 1, globaliter : 147, batch_idx  : 50, triplet_loss : 0.09410948306322098
# epoch : 1, globaliter : 148, batch_idx  : 51, triplet_loss : 0.0942542552947998
# epoch : 1, globaliter : 149, batch_idx  : 52, triplet_loss : 0.09517093002796173
# epoch : 1, globaliter : 150, batch_idx  : 53, triplet_loss : 0.08424748480319977
# epoch : 1, globaliter : 151, batch_idx  : 54, triplet_loss : 0.09322911500930786
# epoch : 1, globaliter : 152, batch_idx  : 55, triplet_loss : 0.08175697177648544
# epoch : 1, globaliter : 153, batch_idx  : 56, triplet_loss : 0.08599897474050522
# epoch : 1, globaliter : 154, batch_idx  : 57, triplet_loss : 0.08806529641151428
# epoch : 1, globaliter : 155, batch_idx  : 58, triplet_loss : 0.0898103415966034
# epoch : 1, globaliter : 156, batch_idx  : 59, triplet_loss : 0.08437042683362961
# epoch : 1, globaliter : 157, batch_idx  : 60, triplet_loss : 0.07970093935728073
# epoch : 1, globaliter : 158, batch_idx  : 61, triplet_loss : 0.09019320458173752
# epoch : 1, globaliter : 159, batch_idx  : 62, triplet_loss : 0.09008588641881943
# epoch : 1, globaliter : 160, batch_idx  : 63, triplet_loss : 0.09470558911561966
# epoch : 1, globaliter : 161, batch_idx  : 64, triplet_loss : 0.08867114037275314
# epoch : 1, globaliter : 162, batch_idx  : 65, triplet_loss : 0.08916027843952179
# epoch : 1, globaliter : 163, batch_idx  : 66, triplet_loss : 0.0852770209312439
# epoch : 1, globaliter : 164, batch_idx  : 67, triplet_loss : 0.08912278711795807
# epoch : 1, globaliter : 165, batch_idx  : 68, triplet_loss : 0.0953834056854248
# epoch : 1, globaliter : 166, batch_idx  : 69, triplet_loss : 0.08764223009347916
# epoch : 1, globaliter : 167, batch_idx  : 70, triplet_loss : 0.08814126998186111
# epoch : 1, globaliter : 168, batch_idx  : 71, triplet_loss : 0.09167923778295517
# epoch : 1, globaliter : 169, batch_idx  : 72, triplet_loss : 0.08988922834396362
# epoch : 1, globaliter : 170, batch_idx  : 73, triplet_loss : 0.09409284591674805
# epoch : 1, globaliter : 171, batch_idx  : 74, triplet_loss : 0.08783850818872452
# epoch : 1, globaliter : 172, batch_idx  : 75, triplet_loss : 0.0865221917629242
# epoch : 1, globaliter : 173, batch_idx  : 76, triplet_loss : 0.08726902306079865
# epoch : 1, globaliter : 174, batch_idx  : 77, triplet_loss : 0.09108928591012955
# epoch : 1, globaliter : 175, batch_idx  : 78, triplet_loss : 0.09093362838029861
# epoch : 1, globaliter : 176, batch_idx  : 79, triplet_loss : 0.08831977844238281
# epoch : 1, globaliter : 177, batch_idx  : 80, triplet_loss : 0.08411084115505219
# epoch : 1, globaliter : 178, batch_idx  : 81, triplet_loss : 0.08974993973970413
# epoch : 1, globaliter : 179, batch_idx  : 82, triplet_loss : 0.08984639495611191
# epoch : 1, globaliter : 180, batch_idx  : 83, triplet_loss : 0.09213150292634964
# epoch : 1, globaliter : 181, batch_idx  : 84, triplet_loss : 0.08949243277311325
# epoch : 1, globaliter : 182, batch_idx  : 85, triplet_loss : 0.0970422625541687
# epoch : 1, globaliter : 183, batch_idx  : 86, triplet_loss : 0.08215416967868805
# epoch : 1, globaliter : 184, batch_idx  : 87, triplet_loss : 0.09540603309869766
# epoch : 1, globaliter : 185, batch_idx  : 88, triplet_loss : 0.0932098925113678
# epoch : 1, globaliter : 186, batch_idx  : 89, triplet_loss : 0.09088939428329468
# epoch : 1, globaliter : 187, batch_idx  : 90, triplet_loss : 0.09241104871034622
# epoch : 1, globaliter : 188, batch_idx  : 91, triplet_loss : 0.09360628575086594
# epoch : 1, globaliter : 189, batch_idx  : 92, triplet_loss : 0.09144614636898041
# epoch : 1, globaliter : 190, batch_idx  : 93, triplet_loss : 0.09143808484077454
# epoch : 1, globaliter : 191, batch_idx  : 94, triplet_loss : 0.08182501047849655
# epoch : 1, globaliter : 192, batch_idx  : 95, triplet_loss : 0.08849292993545532
# epoch : 1, globaliter : 193, batch_idx  : 96, triplet_loss : 0.08610254526138306
# epoch : 2, globaliter : 194, batch_idx  : 0, triplet_loss : 0.09280429780483246
# epoch : 2, globaliter : 195, batch_idx  : 1, triplet_loss : 0.08995699882507324
# epoch : 2, globaliter : 196, batch_idx  : 2, triplet_loss : 0.08549833297729492
# epoch : 2, globaliter : 197, batch_idx  : 3, triplet_loss : 0.09357781708240509
# epoch : 2, globaliter : 198, batch_idx  : 4, triplet_loss : 0.08367869257926941
# epoch : 2, globaliter : 199, batch_idx  : 5, triplet_loss : 0.09466574341058731
# epoch : 2, globaliter : 200, batch_idx  : 6, triplet_loss : 0.08616089820861816
# epoch : 2, globaliter : 201, batch_idx  : 7, triplet_loss : 0.08087287098169327
# epoch : 2, globaliter : 202, batch_idx  : 8, triplet_loss : 0.08971699327230453
# epoch : 2, globaliter : 203, batch_idx  : 9, triplet_loss : 0.08551481366157532
# epoch : 2, globaliter : 204, batch_idx  : 10, triplet_loss : 0.0831848531961441
# epoch : 2, globaliter : 205, batch_idx  : 11, triplet_loss : 0.09253792464733124
# epoch : 2, globaliter : 206, batch_idx  : 12, triplet_loss : 0.09054406732320786
# epoch : 2, globaliter : 207, batch_idx  : 13, triplet_loss : 0.08128942549228668
# epoch : 2, globaliter : 208, batch_idx  : 14, triplet_loss : 0.08576599508523941
# epoch : 2, globaliter : 209, batch_idx  : 15, triplet_loss : 0.09710421413183212
# epoch : 2, globaliter : 210, batch_idx  : 16, triplet_loss : 0.08963194489479065
# epoch : 2, globaliter : 211, batch_idx  : 17, triplet_loss : 0.09057408571243286
# epoch : 2, globaliter : 212, batch_idx  : 18, triplet_loss : 0.0947209820151329
# epoch : 2, globaliter : 213, batch_idx  : 19, triplet_loss : 0.08942805975675583
# epoch : 2, globaliter : 214, batch_idx  : 20, triplet_loss : 0.08713967353105545
# epoch : 2, globaliter : 215, batch_idx  : 21, triplet_loss : 0.09174700826406479
# epoch : 2, globaliter : 216, batch_idx  : 22, triplet_loss : 0.0845431536436081
# epoch : 2, globaliter : 217, batch_idx  : 23, triplet_loss : 0.09217395633459091
# epoch : 2, globaliter : 218, batch_idx  : 24, triplet_loss : 0.0957864448428154
# epoch : 2, globaliter : 219, batch_idx  : 25, triplet_loss : 0.08958051353693008
# epoch : 2, globaliter : 220, batch_idx  : 26, triplet_loss : 0.08378113806247711
# epoch : 2, globaliter : 221, batch_idx  : 27, triplet_loss : 0.09109515696763992
# epoch : 2, globaliter : 222, batch_idx  : 28, triplet_loss : 0.09335994720458984
# epoch : 2, globaliter : 223, batch_idx  : 29, triplet_loss : 0.09588135033845901
# epoch : 2, globaliter : 224, batch_idx  : 30, triplet_loss : 0.088114894926548
# epoch : 2, globaliter : 225, batch_idx  : 31, triplet_loss : 0.08360830694437027
# epoch : 2, globaliter : 226, batch_idx  : 32, triplet_loss : 0.08863382786512375
# epoch : 2, globaliter : 227, batch_idx  : 33, triplet_loss : 0.0881233885884285
# epoch : 2, globaliter : 228, batch_idx  : 34, triplet_loss : 0.08995572477579117
# epoch : 2, globaliter : 229, batch_idx  : 35, triplet_loss : 0.0770694836974144
# epoch : 2, globaliter : 230, batch_idx  : 36, triplet_loss : 0.08095890283584595
# epoch : 2, globaliter : 231, batch_idx  : 37, triplet_loss : 0.08401196449995041
# epoch : 2, globaliter : 232, batch_idx  : 38, triplet_loss : 0.08124378323554993
# epoch : 2, globaliter : 233, batch_idx  : 39, triplet_loss : 0.07261272519826889
# epoch : 2, globaliter : 234, batch_idx  : 40, triplet_loss : 0.08816884458065033
# epoch : 2, globaliter : 235, batch_idx  : 41, triplet_loss : 0.09532534331083298
# epoch : 2, globaliter : 236, batch_idx  : 42, triplet_loss : 0.0763014554977417
# epoch : 2, globaliter : 237, batch_idx  : 43, triplet_loss : 0.09125765413045883
# epoch : 2, globaliter : 238, batch_idx  : 44, triplet_loss : 0.09000227600336075
# epoch : 2, globaliter : 239, batch_idx  : 45, triplet_loss : 0.08694615960121155
# epoch : 2, globaliter : 240, batch_idx  : 46, triplet_loss : 0.08096582442522049
# epoch : 2, globaliter : 241, batch_idx  : 47, triplet_loss : 0.07431615889072418
# epoch : 2, globaliter : 242, batch_idx  : 48, triplet_loss : 0.08825572580099106
# epoch : 2, globaliter : 243, batch_idx  : 49, triplet_loss : 0.09593378752470016
# epoch : 2, globaliter : 244, batch_idx  : 50, triplet_loss : 0.08512170612812042
# epoch : 2, globaliter : 245, batch_idx  : 51, triplet_loss : 0.08543279021978378
# epoch : 2, globaliter : 246, batch_idx  : 52, triplet_loss : 0.08745092898607254
# epoch : 2, globaliter : 247, batch_idx  : 53, triplet_loss : 0.09303707629442215
# epoch : 2, globaliter : 248, batch_idx  : 54, triplet_loss : 0.08347918093204498
# epoch : 2, globaliter : 249, batch_idx  : 55, triplet_loss : 0.08954404294490814
# epoch : 2, globaliter : 250, batch_idx  : 56, triplet_loss : 0.08834181725978851
# epoch : 2, globaliter : 251, batch_idx  : 57, triplet_loss : 0.08715257793664932
# epoch : 2, globaliter : 252, batch_idx  : 58, triplet_loss : 0.0903344675898552
# epoch : 2, globaliter : 253, batch_idx  : 59, triplet_loss : 0.09424534440040588
# epoch : 2, globaliter : 254, batch_idx  : 60, triplet_loss : 0.09035944938659668
# epoch : 2, globaliter : 255, batch_idx  : 61, triplet_loss : 0.09233425557613373
# epoch : 2, globaliter : 256, batch_idx  : 62, triplet_loss : 0.0817824974656105
# epoch : 2, globaliter : 257, batch_idx  : 63, triplet_loss : 0.08667519688606262
# epoch : 2, globaliter : 258, batch_idx  : 64, triplet_loss : 0.07858589291572571
# epoch : 2, globaliter : 259, batch_idx  : 65, triplet_loss : 0.0889146476984024
# epoch : 2, globaliter : 260, batch_idx  : 66, triplet_loss : 0.08795633167028427
# epoch : 2, globaliter : 261, batch_idx  : 67, triplet_loss : 0.08061998337507248
# epoch : 2, globaliter : 262, batch_idx  : 68, triplet_loss : 0.07413007318973541
# epoch : 2, globaliter : 263, batch_idx  : 69, triplet_loss : 0.08688872307538986
# epoch : 2, globaliter : 264, batch_idx  : 70, triplet_loss : 0.08435925841331482
# epoch : 2, globaliter : 265, batch_idx  : 71, triplet_loss : 0.08435682952404022
# epoch : 2, globaliter : 266, batch_idx  : 72, triplet_loss : 0.0905168354511261
# epoch : 2, globaliter : 267, batch_idx  : 73, triplet_loss : 0.08384900540113449
# epoch : 2, globaliter : 268, batch_idx  : 74, triplet_loss : 0.0983782634139061
# epoch : 2, globaliter : 269, batch_idx  : 75, triplet_loss : 0.08229704946279526
# epoch : 2, globaliter : 270, batch_idx  : 76, triplet_loss : 0.07505356520414352
# epoch : 2, globaliter : 271, batch_idx  : 77, triplet_loss : 0.09149207919836044
# epoch : 2, globaliter : 272, batch_idx  : 78, triplet_loss : 0.09477028250694275
# epoch : 2, globaliter : 273, batch_idx  : 79, triplet_loss : 0.0677412822842598
# epoch : 2, globaliter : 274, batch_idx  : 80, triplet_loss : 0.08244963735342026
# epoch : 2, globaliter : 275, batch_idx  : 81, triplet_loss : 0.08888950198888779
# epoch : 2, globaliter : 276, batch_idx  : 82, triplet_loss : 0.07994560152292252
# epoch : 2, globaliter : 277, batch_idx  : 83, triplet_loss : 0.08055416494607925
# epoch : 2, globaliter : 278, batch_idx  : 84, triplet_loss : 0.08589094132184982
# epoch : 2, globaliter : 279, batch_idx  : 85, triplet_loss : 0.08366518467664719
# epoch : 2, globaliter : 280, batch_idx  : 86, triplet_loss : 0.0718892514705658
# epoch : 2, globaliter : 281, batch_idx  : 87, triplet_loss : 0.08422441780567169
# epoch : 2, globaliter : 282, batch_idx  : 88, triplet_loss : 0.060075268149375916
# epoch : 2, globaliter : 283, batch_idx  : 89, triplet_loss : 0.07641701400279999
# epoch : 2, globaliter : 284, batch_idx  : 90, triplet_loss : 0.0864434540271759
# epoch : 2, globaliter : 285, batch_idx  : 91, triplet_loss : 0.0850367546081543
# epoch : 2, globaliter : 286, batch_idx  : 92, triplet_loss : 0.07762765139341354
# epoch : 2, globaliter : 287, batch_idx  : 93, triplet_loss : 0.08917326480150223
# epoch : 2, globaliter : 288, batch_idx  : 94, triplet_loss : 0.07860755175352097
# epoch : 2, globaliter : 289, batch_idx  : 95, triplet_loss : 0.06927383691072464
# epoch : 2, globaliter : 290, batch_idx  : 96, triplet_loss : 0.07530336081981659
# epoch : 3, globaliter : 291, batch_idx  : 0, triplet_loss : 0.08120284229516983
# epoch : 3, globaliter : 292, batch_idx  : 1, triplet_loss : 0.08709716796875
# epoch : 3, globaliter : 293, batch_idx  : 2, triplet_loss : 0.07143503427505493
# epoch : 3, globaliter : 294, batch_idx  : 3, triplet_loss : 0.07003990560770035
# epoch : 3, globaliter : 295, batch_idx  : 4, triplet_loss : 0.08557764440774918
# epoch : 3, globaliter : 296, batch_idx  : 5, triplet_loss : 0.07062514871358871
# epoch : 3, globaliter : 297, batch_idx  : 6, triplet_loss : 0.09111353009939194
# epoch : 3, globaliter : 298, batch_idx  : 7, triplet_loss : 0.0822756215929985
# epoch : 3, globaliter : 299, batch_idx  : 8, triplet_loss : 0.08886080980300903
# epoch : 3, globaliter : 300, batch_idx  : 9, triplet_loss : 0.08535841852426529
# epoch : 3, globaliter : 301, batch_idx  : 10, triplet_loss : 0.09537355601787567
# epoch : 3, globaliter : 302, batch_idx  : 11, triplet_loss : 0.05918292701244354
# epoch : 3, globaliter : 303, batch_idx  : 12, triplet_loss : 0.07716172933578491
# epoch : 3, globaliter : 304, batch_idx  : 13, triplet_loss : 0.07786846160888672
# epoch : 3, globaliter : 305, batch_idx  : 14, triplet_loss : 0.07125625759363174
# epoch : 3, globaliter : 306, batch_idx  : 15, triplet_loss : 0.07060228288173676
# epoch : 3, globaliter : 307, batch_idx  : 16, triplet_loss : 0.08760630339384079
# epoch : 3, globaliter : 308, batch_idx  : 17, triplet_loss : 0.08077944815158844
# epoch : 3, globaliter : 309, batch_idx  : 18, triplet_loss : 0.0816023200750351
# epoch : 3, globaliter : 310, batch_idx  : 19, triplet_loss : 0.07125972956418991
# epoch : 3, globaliter : 311, batch_idx  : 20, triplet_loss : 0.07269816845655441
# epoch : 3, globaliter : 312, batch_idx  : 21, triplet_loss : 0.08777869492769241
# epoch : 3, globaliter : 313, batch_idx  : 22, triplet_loss : 0.08335179835557938
# epoch : 3, globaliter : 314, batch_idx  : 23, triplet_loss : 0.09178964048624039
# epoch : 3, globaliter : 315, batch_idx  : 24, triplet_loss : 0.06667505949735641
# epoch : 3, globaliter : 316, batch_idx  : 25, triplet_loss : 0.07558264583349228
# epoch : 3, globaliter : 317, batch_idx  : 26, triplet_loss : 0.07287748903036118
# epoch : 3, globaliter : 318, batch_idx  : 27, triplet_loss : 0.07931621372699738
# epoch : 3, globaliter : 319, batch_idx  : 28, triplet_loss : 0.08831404149532318
# epoch : 3, globaliter : 320, batch_idx  : 29, triplet_loss : 0.07915523648262024
# epoch : 3, globaliter : 321, batch_idx  : 30, triplet_loss : 0.07674214243888855
# epoch : 3, globaliter : 322, batch_idx  : 31, triplet_loss : 0.08304573595523834
# epoch : 3, globaliter : 323, batch_idx  : 32, triplet_loss : 0.06898871809244156
# epoch : 3, globaliter : 324, batch_idx  : 33, triplet_loss : 0.06270793825387955
# epoch : 3, globaliter : 325, batch_idx  : 34, triplet_loss : 0.07879265397787094
# epoch : 3, globaliter : 326, batch_idx  : 35, triplet_loss : 0.0832960233092308
# epoch : 3, globaliter : 327, batch_idx  : 36, triplet_loss : 0.08371040225028992
# epoch : 3, globaliter : 328, batch_idx  : 37, triplet_loss : 0.0837041363120079
# epoch : 3, globaliter : 329, batch_idx  : 38, triplet_loss : 0.07872898131608963
# epoch : 3, globaliter : 330, batch_idx  : 39, triplet_loss : 0.07104950398206711
# epoch : 3, globaliter : 331, batch_idx  : 40, triplet_loss : 0.09490164369344711
# epoch : 3, globaliter : 332, batch_idx  : 41, triplet_loss : 0.08722472935914993
# epoch : 3, globaliter : 333, batch_idx  : 42, triplet_loss : 0.08115304261445999
# epoch : 3, globaliter : 334, batch_idx  : 43, triplet_loss : 0.07407745718955994
# epoch : 3, globaliter : 335, batch_idx  : 44, triplet_loss : 0.06522868573665619
# epoch : 3, globaliter : 336, batch_idx  : 45, triplet_loss : 0.07163549959659576
# epoch : 3, globaliter : 337, batch_idx  : 46, triplet_loss : 0.07326614111661911
# epoch : 3, globaliter : 338, batch_idx  : 47, triplet_loss : 0.0810956358909607
# epoch : 3, globaliter : 339, batch_idx  : 48, triplet_loss : 0.08104370534420013
# epoch : 3, globaliter : 340, batch_idx  : 49, triplet_loss : 0.07413359731435776
# epoch : 3, globaliter : 341, batch_idx  : 50, triplet_loss : 0.06688437610864639
# epoch : 3, globaliter : 342, batch_idx  : 51, triplet_loss : 0.07496512681245804
# epoch : 3, globaliter : 343, batch_idx  : 52, triplet_loss : 0.08877447247505188
# epoch : 3, globaliter : 344, batch_idx  : 53, triplet_loss : 0.0760965645313263
# epoch : 3, globaliter : 345, batch_idx  : 54, triplet_loss : 0.06228775158524513
# epoch : 3, globaliter : 346, batch_idx  : 55, triplet_loss : 0.07252421975135803
# epoch : 3, globaliter : 347, batch_idx  : 56, triplet_loss : 0.08123937994241714
# epoch : 3, globaliter : 348, batch_idx  : 57, triplet_loss : 0.060032714158296585
# epoch : 3, globaliter : 349, batch_idx  : 58, triplet_loss : 0.08434805274009705
# epoch : 3, globaliter : 350, batch_idx  : 59, triplet_loss : 0.07520338147878647
# epoch : 3, globaliter : 351, batch_idx  : 60, triplet_loss : 0.06310351938009262
# epoch : 3, globaliter : 352, batch_idx  : 61, triplet_loss : 0.05317115783691406
# epoch : 3, globaliter : 353, batch_idx  : 62, triplet_loss : 0.0695262923836708
# epoch : 3, globaliter : 354, batch_idx  : 63, triplet_loss : 0.08427230268716812
# epoch : 3, globaliter : 355, batch_idx  : 64, triplet_loss : 0.06655359268188477
# epoch : 3, globaliter : 356, batch_idx  : 65, triplet_loss : 0.07617273181676865
# epoch : 3, globaliter : 357, batch_idx  : 66, triplet_loss : 0.06826002150774002
# epoch : 3, globaliter : 358, batch_idx  : 67, triplet_loss : 0.07053623348474503
# epoch : 3, globaliter : 359, batch_idx  : 68, triplet_loss : 0.0679432675242424
# epoch : 3, globaliter : 360, batch_idx  : 69, triplet_loss : 0.07089023292064667
# epoch : 3, globaliter : 361, batch_idx  : 70, triplet_loss : 0.08152593672275543
# epoch : 3, globaliter : 362, batch_idx  : 71, triplet_loss : 0.06660328060388565
# epoch : 3, globaliter : 363, batch_idx  : 72, triplet_loss : 0.08123397082090378
# epoch : 3, globaliter : 364, batch_idx  : 73, triplet_loss : 0.08567671477794647
# epoch : 3, globaliter : 365, batch_idx  : 74, triplet_loss : 0.08280796557664871
# epoch : 3, globaliter : 366, batch_idx  : 75, triplet_loss : 0.08278371393680573
# epoch : 3, globaliter : 367, batch_idx  : 76, triplet_loss : 0.07387606054544449
# epoch : 3, globaliter : 368, batch_idx  : 77, triplet_loss : 0.08372995257377625
# epoch : 3, globaliter : 369, batch_idx  : 78, triplet_loss : 0.08017587661743164
# epoch : 3, globaliter : 370, batch_idx  : 79, triplet_loss : 0.08558633923530579
# epoch : 3, globaliter : 371, batch_idx  : 80, triplet_loss : 0.08597163110971451
# epoch : 3, globaliter : 372, batch_idx  : 81, triplet_loss : 0.06355629116296768
# epoch : 3, globaliter : 373, batch_idx  : 82, triplet_loss : 0.08656641095876694
# epoch : 3, globaliter : 374, batch_idx  : 83, triplet_loss : 0.06348538398742676
# epoch : 3, globaliter : 375, batch_idx  : 84, triplet_loss : 0.07472730427980423
# epoch : 3, globaliter : 376, batch_idx  : 85, triplet_loss : 0.07963471859693527
# epoch : 3, globaliter : 377, batch_idx  : 86, triplet_loss : 0.06918022781610489
# epoch : 3, globaliter : 378, batch_idx  : 87, triplet_loss : 0.07362977415323257
# epoch : 3, globaliter : 379, batch_idx  : 88, triplet_loss : 0.07442142069339752
# epoch : 3, globaliter : 380, batch_idx  : 89, triplet_loss : 0.05300914868712425
# epoch : 3, globaliter : 381, batch_idx  : 90, triplet_loss : 0.08742303401231766
# epoch : 3, globaliter : 382, batch_idx  : 91, triplet_loss : 0.087490513920784
# epoch : 3, globaliter : 383, batch_idx  : 92, triplet_loss : 0.09585592895746231
# epoch : 3, globaliter : 384, batch_idx  : 93, triplet_loss : 0.0588190034031868
# epoch : 3, globaliter : 385, batch_idx  : 94, triplet_loss : 0.08962783962488174
# epoch : 3, globaliter : 386, batch_idx  : 95, triplet_loss : 0.08275379985570908
# epoch : 3, globaliter : 387, batch_idx  : 96, triplet_loss : 0.06790405511856079
# epoch : 4, globaliter : 388, batch_idx  : 0, triplet_loss : 0.07316485047340393
# epoch : 4, globaliter : 389, batch_idx  : 1, triplet_loss : 0.07839565724134445
# epoch : 4, globaliter : 390, batch_idx  : 2, triplet_loss : 0.06245112419128418
# epoch : 4, globaliter : 391, batch_idx  : 3, triplet_loss : 0.0751742571592331
# epoch : 4, globaliter : 392, batch_idx  : 4, triplet_loss : 0.07030981779098511
# epoch : 4, globaliter : 393, batch_idx  : 5, triplet_loss : 0.06399417668581009
# epoch : 4, globaliter : 394, batch_idx  : 6, triplet_loss : 0.07531844079494476
# epoch : 4, globaliter : 395, batch_idx  : 7, triplet_loss : 0.057492971420288086
# epoch : 4, globaliter : 396, batch_idx  : 8, triplet_loss : 0.06484915316104889
# epoch : 4, globaliter : 397, batch_idx  : 9, triplet_loss : 0.08733541518449783
# epoch : 4, globaliter : 398, batch_idx  : 10, triplet_loss : 0.08195604383945465
# epoch : 4, globaliter : 399, batch_idx  : 11, triplet_loss : 0.08095937222242355
# epoch : 4, globaliter : 400, batch_idx  : 12, triplet_loss : 0.07635284215211868
# epoch : 4, globaliter : 401, batch_idx  : 13, triplet_loss : 0.07030244916677475
# epoch : 4, globaliter : 402, batch_idx  : 14, triplet_loss : 0.06803203374147415
# epoch : 4, globaliter : 403, batch_idx  : 15, triplet_loss : 0.07782867550849915
# epoch : 4, globaliter : 404, batch_idx  : 16, triplet_loss : 0.07065629214048386
# epoch : 4, globaliter : 405, batch_idx  : 17, triplet_loss : 0.057864345610141754
# epoch : 4, globaliter : 406, batch_idx  : 18, triplet_loss : 0.052785445004701614
# epoch : 4, globaliter : 407, batch_idx  : 19, triplet_loss : 0.054820798337459564
# epoch : 4, globaliter : 408, batch_idx  : 20, triplet_loss : 0.07128698378801346
# epoch : 4, globaliter : 409, batch_idx  : 21, triplet_loss : 0.07836537063121796
# epoch : 4, globaliter : 410, batch_idx  : 22, triplet_loss : 0.05535103753209114
# epoch : 4, globaliter : 411, batch_idx  : 23, triplet_loss : 0.062289945781230927
# epoch : 4, globaliter : 412, batch_idx  : 24, triplet_loss : 0.0759454295039177
# epoch : 4, globaliter : 413, batch_idx  : 25, triplet_loss : 0.05758174881339073
# epoch : 4, globaliter : 414, batch_idx  : 26, triplet_loss : 0.07104230672121048
# epoch : 4, globaliter : 415, batch_idx  : 27, triplet_loss : 0.07260254770517349
# epoch : 4, globaliter : 416, batch_idx  : 28, triplet_loss : 0.06643020361661911
# epoch : 4, globaliter : 417, batch_idx  : 29, triplet_loss : 0.050178151577711105
# epoch : 4, globaliter : 418, batch_idx  : 30, triplet_loss : 0.06375527381896973
# epoch : 4, globaliter : 419, batch_idx  : 31, triplet_loss : 0.04942589998245239
# epoch : 4, globaliter : 420, batch_idx  : 32, triplet_loss : 0.06269719451665878
# epoch : 4, globaliter : 421, batch_idx  : 33, triplet_loss : 0.0846925601363182
# epoch : 4, globaliter : 422, batch_idx  : 34, triplet_loss : 0.061083029955625534
# epoch : 4, globaliter : 423, batch_idx  : 35, triplet_loss : 0.07302123308181763
# epoch : 4, globaliter : 424, batch_idx  : 36, triplet_loss : 0.0752398669719696
# epoch : 4, globaliter : 425, batch_idx  : 37, triplet_loss : 0.060474976897239685
# epoch : 4, globaliter : 426, batch_idx  : 38, triplet_loss : 0.05824447423219681
# epoch : 4, globaliter : 427, batch_idx  : 39, triplet_loss : 0.05999915301799774
# epoch : 4, globaliter : 428, batch_idx  : 40, triplet_loss : 0.055182941257953644
# epoch : 4, globaliter : 429, batch_idx  : 41, triplet_loss : 0.07934893667697906
# epoch : 4, globaliter : 430, batch_idx  : 42, triplet_loss : 0.08207198977470398
# epoch : 4, globaliter : 431, batch_idx  : 43, triplet_loss : 0.08400653302669525
# epoch : 4, globaliter : 432, batch_idx  : 44, triplet_loss : 0.065149687230587
# epoch : 4, globaliter : 433, batch_idx  : 45, triplet_loss : 0.072017602622509
# epoch : 4, globaliter : 434, batch_idx  : 46, triplet_loss : 0.07052741944789886
# epoch : 4, globaliter : 435, batch_idx  : 47, triplet_loss : 0.06603450328111649
# epoch : 4, globaliter : 436, batch_idx  : 48, triplet_loss : 0.056925058364868164
# epoch : 4, globaliter : 437, batch_idx  : 49, triplet_loss : 0.06794992834329605
# epoch : 4, globaliter : 438, batch_idx  : 50, triplet_loss : 0.059044111520051956
# epoch : 4, globaliter : 439, batch_idx  : 51, triplet_loss : 0.06537625193595886
# epoch : 4, globaliter : 440, batch_idx  : 52, triplet_loss : 0.08474156260490417
# epoch : 4, globaliter : 441, batch_idx  : 53, triplet_loss : 0.08274079114198685
# epoch : 4, globaliter : 442, batch_idx  : 54, triplet_loss : 0.06249343976378441
# epoch : 4, globaliter : 443, batch_idx  : 55, triplet_loss : 0.05663863196969032
# epoch : 4, globaliter : 444, batch_idx  : 56, triplet_loss : 0.09366590529680252
# epoch : 4, globaliter : 445, batch_idx  : 57, triplet_loss : 0.06461718678474426
# epoch : 4, globaliter : 446, batch_idx  : 58, triplet_loss : 0.058593034744262695
# epoch : 4, globaliter : 447, batch_idx  : 59, triplet_loss : 0.05841823294758797
# epoch : 4, globaliter : 448, batch_idx  : 60, triplet_loss : 0.08295483887195587
# epoch : 4, globaliter : 449, batch_idx  : 61, triplet_loss : 0.06289593130350113
# epoch : 4, globaliter : 450, batch_idx  : 62, triplet_loss : 0.06368336081504822
# epoch : 4, globaliter : 451, batch_idx  : 63, triplet_loss : 0.05038949474692345
# epoch : 4, globaliter : 452, batch_idx  : 64, triplet_loss : 0.08819955587387085
# epoch : 4, globaliter : 453, batch_idx  : 65, triplet_loss : 0.07035533338785172
# epoch : 4, globaliter : 454, batch_idx  : 66, triplet_loss : 0.04888463020324707
# epoch : 4, globaliter : 455, batch_idx  : 67, triplet_loss : 0.07785423845052719
# epoch : 4, globaliter : 456, batch_idx  : 68, triplet_loss : 0.07446137070655823
# epoch : 4, globaliter : 457, batch_idx  : 69, triplet_loss : 0.056391652673482895
# epoch : 4, globaliter : 458, batch_idx  : 70, triplet_loss : 0.06971827149391174
# epoch : 4, globaliter : 459, batch_idx  : 71, triplet_loss : 0.0727226659655571
# epoch : 4, globaliter : 460, batch_idx  : 72, triplet_loss : 0.03920545056462288
# epoch : 4, globaliter : 461, batch_idx  : 73, triplet_loss : 0.041596148163080215
# epoch : 4, globaliter : 462, batch_idx  : 74, triplet_loss : 0.05835831165313721
# epoch : 4, globaliter : 463, batch_idx  : 75, triplet_loss : 0.07592568546533585
# epoch : 4, globaliter : 464, batch_idx  : 76, triplet_loss : 0.0397569015622139
# epoch : 4, globaliter : 465, batch_idx  : 77, triplet_loss : 0.05263221263885498
# epoch : 4, globaliter : 466, batch_idx  : 78, triplet_loss : 0.04907756671309471
# epoch : 4, globaliter : 467, batch_idx  : 79, triplet_loss : 0.07362493127584457
# epoch : 4, globaliter : 468, batch_idx  : 80, triplet_loss : 0.06393971294164658
# epoch : 4, globaliter : 469, batch_idx  : 81, triplet_loss : 0.06599590182304382
# epoch : 4, globaliter : 470, batch_idx  : 82, triplet_loss : 0.06593002378940582
# epoch : 4, globaliter : 471, batch_idx  : 83, triplet_loss : 0.05986109748482704
# epoch : 4, globaliter : 472, batch_idx  : 84, triplet_loss : 0.06162990629673004
# epoch : 4, globaliter : 473, batch_idx  : 85, triplet_loss : 0.05757501348853111
# epoch : 4, globaliter : 474, batch_idx  : 86, triplet_loss : 0.041449807584285736
# epoch : 4, globaliter : 475, batch_idx  : 87, triplet_loss : 0.06439724564552307
# epoch : 4, globaliter : 476, batch_idx  : 88, triplet_loss : 0.04875383898615837
# epoch : 4, globaliter : 477, batch_idx  : 89, triplet_loss : 0.05712488666176796
# epoch : 4, globaliter : 478, batch_idx  : 90, triplet_loss : 0.05860607698559761
# epoch : 4, globaliter : 479, batch_idx  : 91, triplet_loss : 0.08451838046312332
# epoch : 4, globaliter : 480, batch_idx  : 92, triplet_loss : 0.06782329082489014
# epoch : 4, globaliter : 481, batch_idx  : 93, triplet_loss : 0.07203973084688187
# epoch : 4, globaliter : 482, batch_idx  : 94, triplet_loss : 0.06493625789880753
# epoch : 4, globaliter : 483, batch_idx  : 95, triplet_loss : 0.05810840055346489
# epoch : 4, globaliter : 484, batch_idx  : 96, triplet_loss : 0.05387447029352188
# epoch : 5, globaliter : 485, batch_idx  : 0, triplet_loss : 0.06016568839550018
# epoch : 5, globaliter : 486, batch_idx  : 1, triplet_loss : 0.08464975655078888
# epoch : 5, globaliter : 487, batch_idx  : 2, triplet_loss : 0.03967975825071335
# epoch : 5, globaliter : 488, batch_idx  : 3, triplet_loss : 0.05959472805261612
# epoch : 5, globaliter : 489, batch_idx  : 4, triplet_loss : 0.055999524891376495
# epoch : 5, globaliter : 490, batch_idx  : 5, triplet_loss : 0.04519988223910332
# epoch : 5, globaliter : 491, batch_idx  : 6, triplet_loss : 0.06615366786718369
# epoch : 5, globaliter : 492, batch_idx  : 7, triplet_loss : 0.06148172914981842
# epoch : 5, globaliter : 493, batch_idx  : 8, triplet_loss : 0.054324131458997726
# epoch : 5, globaliter : 494, batch_idx  : 9, triplet_loss : 0.06515821814537048
# epoch : 5, globaliter : 495, batch_idx  : 10, triplet_loss : 0.06876147538423538
# epoch : 5, globaliter : 496, batch_idx  : 11, triplet_loss : 0.07735230028629303
# epoch : 5, globaliter : 497, batch_idx  : 12, triplet_loss : 0.06956601142883301
# epoch : 5, globaliter : 498, batch_idx  : 13, triplet_loss : 0.05905365198850632
# epoch : 5, globaliter : 499, batch_idx  : 14, triplet_loss : 0.048352863639593124
# epoch : 5, globaliter : 500, batch_idx  : 15, triplet_loss : 0.05588383600115776
# epoch : 5, globaliter : 501, batch_idx  : 16, triplet_loss : 0.052247583866119385
# epoch : 5, globaliter : 502, batch_idx  : 17, triplet_loss : 0.06759078055620193
# epoch : 5, globaliter : 503, batch_idx  : 18, triplet_loss : 0.05007239803671837
# epoch : 5, globaliter : 504, batch_idx  : 19, triplet_loss : 0.07858940958976746
# epoch : 5, globaliter : 505, batch_idx  : 20, triplet_loss : 0.046778805553913116
# epoch : 5, globaliter : 506, batch_idx  : 21, triplet_loss : 0.0420442558825016
# epoch : 5, globaliter : 507, batch_idx  : 22, triplet_loss : 0.06735286861658096
# epoch : 5, globaliter : 508, batch_idx  : 23, triplet_loss : 0.03149031847715378
# epoch : 5, globaliter : 509, batch_idx  : 24, triplet_loss : 0.04282516986131668
# epoch : 5, globaliter : 510, batch_idx  : 25, triplet_loss : 0.07222557067871094
# epoch : 5, globaliter : 511, batch_idx  : 26, triplet_loss : 0.05911269411444664
# epoch : 5, globaliter : 512, batch_idx  : 27, triplet_loss : 0.05772741138935089
# epoch : 5, globaliter : 513, batch_idx  : 28, triplet_loss : 0.04991545155644417
# epoch : 5, globaliter : 514, batch_idx  : 29, triplet_loss : 0.05665040388703346
# epoch : 5, globaliter : 515, batch_idx  : 30, triplet_loss : 0.05730128288269043
# epoch : 5, globaliter : 516, batch_idx  : 31, triplet_loss : 0.07562214136123657
# epoch : 5, globaliter : 517, batch_idx  : 32, triplet_loss : 0.03218835964798927
# epoch : 5, globaliter : 518, batch_idx  : 33, triplet_loss : 0.05347398295998573
# epoch : 5, globaliter : 519, batch_idx  : 34, triplet_loss : 0.06788671016693115
# epoch : 5, globaliter : 520, batch_idx  : 35, triplet_loss : 0.04879602789878845
# epoch : 5, globaliter : 521, batch_idx  : 36, triplet_loss : 0.03015773370862007
# epoch : 5, globaliter : 522, batch_idx  : 37, triplet_loss : 0.044152695685625076
# epoch : 5, globaliter : 523, batch_idx  : 38, triplet_loss : 0.08627551048994064
# epoch : 5, globaliter : 524, batch_idx  : 39, triplet_loss : 0.07106395810842514
# epoch : 5, globaliter : 525, batch_idx  : 40, triplet_loss : 0.07086464762687683
# epoch : 5, globaliter : 526, batch_idx  : 41, triplet_loss : 0.04191219434142113
# epoch : 5, globaliter : 527, batch_idx  : 42, triplet_loss : 0.05947275832295418
# epoch : 5, globaliter : 528, batch_idx  : 43, triplet_loss : 0.08515474945306778
# epoch : 5, globaliter : 529, batch_idx  : 44, triplet_loss : 0.06345293670892715
# epoch : 5, globaliter : 530, batch_idx  : 45, triplet_loss : 0.06786619126796722
# epoch : 5, globaliter : 531, batch_idx  : 46, triplet_loss : 0.04593979939818382
# epoch : 5, globaliter : 532, batch_idx  : 47, triplet_loss : 0.04524833709001541
# epoch : 5, globaliter : 533, batch_idx  : 48, triplet_loss : 0.07585760205984116
# epoch : 5, globaliter : 534, batch_idx  : 49, triplet_loss : 0.04271189123392105
# epoch : 5, globaliter : 535, batch_idx  : 50, triplet_loss : 0.07202384620904922
# epoch : 5, globaliter : 536, batch_idx  : 51, triplet_loss : 0.054196979850530624
# epoch : 5, globaliter : 537, batch_idx  : 52, triplet_loss : 0.06363864988088608
# epoch : 5, globaliter : 538, batch_idx  : 53, triplet_loss : 0.06440507620573044
# epoch : 5, globaliter : 539, batch_idx  : 54, triplet_loss : 0.0493854396045208
# epoch : 5, globaliter : 540, batch_idx  : 55, triplet_loss : 0.07784818112850189
# epoch : 5, globaliter : 541, batch_idx  : 56, triplet_loss : 0.04963788390159607
# epoch : 5, globaliter : 542, batch_idx  : 57, triplet_loss : 0.04898565635085106
# epoch : 5, globaliter : 543, batch_idx  : 58, triplet_loss : 0.0693112462759018
# epoch : 5, globaliter : 544, batch_idx  : 59, triplet_loss : 0.0598154254257679
# epoch : 5, globaliter : 545, batch_idx  : 60, triplet_loss : 0.04612632468342781
# epoch : 5, globaliter : 546, batch_idx  : 61, triplet_loss : 0.07543392479419708
# epoch : 5, globaliter : 547, batch_idx  : 62, triplet_loss : 0.05609261244535446
# epoch : 5, globaliter : 548, batch_idx  : 63, triplet_loss : 0.04447391256690025
# epoch : 5, globaliter : 549, batch_idx  : 64, triplet_loss : 0.06261219829320908
# epoch : 5, globaliter : 550, batch_idx  : 65, triplet_loss : 0.02840602397918701
# epoch : 5, globaliter : 551, batch_idx  : 66, triplet_loss : 0.026315608993172646
# epoch : 5, globaliter : 552, batch_idx  : 67, triplet_loss : 0.04081714153289795
# epoch : 5, globaliter : 553, batch_idx  : 68, triplet_loss : 0.07496976852416992
# epoch : 5, globaliter : 554, batch_idx  : 69, triplet_loss : 0.06104975566267967
# epoch : 5, globaliter : 555, batch_idx  : 70, triplet_loss : 0.08117388188838959
# epoch : 5, globaliter : 556, batch_idx  : 71, triplet_loss : 0.046761125326156616
# epoch : 5, globaliter : 557, batch_idx  : 72, triplet_loss : 0.047972194850444794
# epoch : 5, globaliter : 558, batch_idx  : 73, triplet_loss : 0.06459023058414459
# epoch : 5, globaliter : 559, batch_idx  : 74, triplet_loss : 0.05749965459108353
# epoch : 5, globaliter : 560, batch_idx  : 75, triplet_loss : 0.03572700917720795
# epoch : 5, globaliter : 561, batch_idx  : 76, triplet_loss : 0.04631642997264862
# epoch : 5, globaliter : 562, batch_idx  : 77, triplet_loss : 0.060554247349500656
# epoch : 5, globaliter : 563, batch_idx  : 78, triplet_loss : 0.03648068383336067
# epoch : 5, globaliter : 564, batch_idx  : 79, triplet_loss : 0.056527383625507355
# epoch : 5, globaliter : 565, batch_idx  : 80, triplet_loss : 0.05876404792070389
# epoch : 5, globaliter : 566, batch_idx  : 81, triplet_loss : 0.04934724047780037
# epoch : 5, globaliter : 567, batch_idx  : 82, triplet_loss : 0.0497538186609745
# epoch : 5, globaliter : 568, batch_idx  : 83, triplet_loss : 0.049520380795001984
# epoch : 5, globaliter : 569, batch_idx  : 84, triplet_loss : 0.039418578147888184
# epoch : 5, globaliter : 570, batch_idx  : 85, triplet_loss : 0.0783538669347763
# epoch : 5, globaliter : 571, batch_idx  : 86, triplet_loss : 0.042683131992816925
# epoch : 5, globaliter : 572, batch_idx  : 87, triplet_loss : 0.05106274411082268
# epoch : 5, globaliter : 573, batch_idx  : 88, triplet_loss : 0.04269210621714592
# epoch : 5, globaliter : 574, batch_idx  : 89, triplet_loss : 0.06789277493953705
# epoch : 5, globaliter : 575, batch_idx  : 90, triplet_loss : 0.04581831023097038
# epoch : 5, globaliter : 576, batch_idx  : 91, triplet_loss : 0.05763562396168709
# epoch : 5, globaliter : 577, batch_idx  : 92, triplet_loss : 0.05405596271157265
# epoch : 5, globaliter : 578, batch_idx  : 93, triplet_loss : 0.061626262962818146
# epoch : 5, globaliter : 579, batch_idx  : 94, triplet_loss : 0.055366069078445435
# epoch : 5, globaliter : 580, batch_idx  : 95, triplet_loss : 0.048610903322696686
# epoch : 5, globaliter : 581, batch_idx  : 96, triplet_loss : 0.05232779309153557
# epoch : 6, globaliter : 582, batch_idx  : 0, triplet_loss : 0.059574391692876816
# epoch : 6, globaliter : 583, batch_idx  : 1, triplet_loss : 0.05316323786973953
# epoch : 6, globaliter : 584, batch_idx  : 2, triplet_loss : 0.08254264295101166
# epoch : 6, globaliter : 585, batch_idx  : 3, triplet_loss : 0.0648634061217308
# epoch : 6, globaliter : 586, batch_idx  : 4, triplet_loss : 0.05996145308017731
# epoch : 6, globaliter : 587, batch_idx  : 5, triplet_loss : 0.03580405190587044
# epoch : 6, globaliter : 588, batch_idx  : 6, triplet_loss : 0.057391274720430374
# epoch : 6, globaliter : 589, batch_idx  : 7, triplet_loss : 0.06516291201114655
# epoch : 6, globaliter : 590, batch_idx  : 8, triplet_loss : 0.052198875695466995
# epoch : 6, globaliter : 591, batch_idx  : 9, triplet_loss : 0.05589550733566284
# epoch : 6, globaliter : 592, batch_idx  : 10, triplet_loss : 0.05281469598412514
# epoch : 6, globaliter : 593, batch_idx  : 11, triplet_loss : 0.06115030124783516
# epoch : 6, globaliter : 594, batch_idx  : 12, triplet_loss : 0.04321751743555069
# ...
# epoch : 47, globaliter : 4645, batch_idx  : 86, triplet_loss : 0.0
# epoch : 47, globaliter : 4646, batch_idx  : 87, triplet_loss : 0.011119827628135681
# epoch : 47, globaliter : 4647, batch_idx  : 88, triplet_loss : 0.005229920614510775
# epoch : 47, globaliter : 4648, batch_idx  : 89, triplet_loss : 0.020007185637950897
# epoch : 47, globaliter : 4649, batch_idx  : 90, triplet_loss : 0.0020732830744236708
# epoch : 47, globaliter : 4650, batch_idx  : 91, triplet_loss : 0.0037210509181022644
# epoch : 47, globaliter : 4651, batch_idx  : 92, triplet_loss : 0.0
# epoch : 47, globaliter : 4652, batch_idx  : 93, triplet_loss : 0.002350745489820838
# epoch : 47, globaliter : 4653, batch_idx  : 94, triplet_loss : 0.0
# epoch : 47, globaliter : 4654, batch_idx  : 95, triplet_loss : 0.002848847536370158
# epoch : 47, globaliter : 4655, batch_idx  : 96, triplet_loss : 0.00122036412358284
# epoch : 48, globaliter : 4656, batch_idx  : 0, triplet_loss : 0.003650547005236149
# epoch : 48, globaliter : 4657, batch_idx  : 1, triplet_loss : 0.00037736445665359497
# epoch : 48, globaliter : 4658, batch_idx  : 2, triplet_loss : 0.02151813916862011
# epoch : 48, globaliter : 4659, batch_idx  : 3, triplet_loss : 0.0
# epoch : 48, globaliter : 4660, batch_idx  : 4, triplet_loss : 0.0024876482784748077
# epoch : 48, globaliter : 4661, batch_idx  : 5, triplet_loss : 0.0
# epoch : 48, globaliter : 4662, batch_idx  : 6, triplet_loss : 0.004034174140542746
# epoch : 48, globaliter : 4663, batch_idx  : 7, triplet_loss : 0.0
# epoch : 48, globaliter : 4664, batch_idx  : 8, triplet_loss : 0.0
# epoch : 48, globaliter : 4665, batch_idx  : 9, triplet_loss : 0.0
# epoch : 48, globaliter : 4666, batch_idx  : 10, triplet_loss : 0.00036370009183883667
# epoch : 48, globaliter : 4667, batch_idx  : 11, triplet_loss : 0.0031306110322475433
# epoch : 48, globaliter : 4668, batch_idx  : 12, triplet_loss : 0.004592887591570616
# epoch : 48, globaliter : 4669, batch_idx  : 13, triplet_loss : 0.0034081414341926575
# epoch : 48, globaliter : 4670, batch_idx  : 14, triplet_loss : 0.002974205883219838
# epoch : 48, globaliter : 4671, batch_idx  : 15, triplet_loss : 0.0030119630973786116
# epoch : 48, globaliter : 4672, batch_idx  : 16, triplet_loss : 0.0026710359379649162
# epoch : 48, globaliter : 4673, batch_idx  : 17, triplet_loss : 0.008530777879059315
# epoch : 48, globaliter : 4674, batch_idx  : 18, triplet_loss : 0.0059098354540765285
# epoch : 48, globaliter : 4675, batch_idx  : 19, triplet_loss : 0.005094427149742842
# epoch : 48, globaliter : 4676, batch_idx  : 20, triplet_loss : 0.002336769597604871
# epoch : 48, globaliter : 4677, batch_idx  : 21, triplet_loss : 0.0010779425501823425
# epoch : 48, globaliter : 4678, batch_idx  : 22, triplet_loss : 0.009739289991557598
# epoch : 48, globaliter : 4679, batch_idx  : 23, triplet_loss : 0.000463421136373654
# epoch : 48, globaliter : 4680, batch_idx  : 24, triplet_loss : 0.0
# epoch : 48, globaliter : 4681, batch_idx  : 25, triplet_loss : 0.002359241247177124
# epoch : 48, globaliter : 4682, batch_idx  : 26, triplet_loss : 0.027015715837478638
# epoch : 48, globaliter : 4683, batch_idx  : 27, triplet_loss : 0.0011258721351623535
# epoch : 48, globaliter : 4684, batch_idx  : 28, triplet_loss : 0.0
# epoch : 48, globaliter : 4685, batch_idx  : 29, triplet_loss : 0.0019632726907730103
# epoch : 48, globaliter : 4686, batch_idx  : 30, triplet_loss : 0.0
# epoch : 48, globaliter : 4687, batch_idx  : 31, triplet_loss : 0.0
# epoch : 48, globaliter : 4688, batch_idx  : 32, triplet_loss : 0.0
# epoch : 48, globaliter : 4689, batch_idx  : 33, triplet_loss : 0.0033186774235218763
# epoch : 48, globaliter : 4690, batch_idx  : 34, triplet_loss : 0.0
# epoch : 48, globaliter : 4691, batch_idx  : 35, triplet_loss : 0.0
# epoch : 48, globaliter : 4692, batch_idx  : 36, triplet_loss : 0.0
# epoch : 48, globaliter : 4693, batch_idx  : 37, triplet_loss : 0.008184260688722134
# epoch : 48, globaliter : 4694, batch_idx  : 38, triplet_loss : 0.0012123063206672668
# epoch : 48, globaliter : 4695, batch_idx  : 39, triplet_loss : 0.0011535389348864555
# epoch : 48, globaliter : 4696, batch_idx  : 40, triplet_loss : 0.0
# epoch : 48, globaliter : 4697, batch_idx  : 41, triplet_loss : 0.0
# epoch : 48, globaliter : 4698, batch_idx  : 42, triplet_loss : 0.0024832189083099365
# epoch : 48, globaliter : 4699, batch_idx  : 43, triplet_loss : 0.021325333043932915
# epoch : 48, globaliter : 4700, batch_idx  : 44, triplet_loss : 0.0
# epoch : 48, globaliter : 4701, batch_idx  : 45, triplet_loss : 0.0
# epoch : 48, globaliter : 4702, batch_idx  : 46, triplet_loss : 0.02121124230325222
# epoch : 48, globaliter : 4703, batch_idx  : 47, triplet_loss : 0.0009019494173116982
# epoch : 48, globaliter : 4704, batch_idx  : 48, triplet_loss : 0.00199811696074903
# epoch : 48, globaliter : 4705, batch_idx  : 49, triplet_loss : 0.02080601453781128
# epoch : 48, globaliter : 4706, batch_idx  : 50, triplet_loss : 0.007028029765933752
# epoch : 48, globaliter : 4707, batch_idx  : 51, triplet_loss : 0.009550333954393864
# epoch : 48, globaliter : 4708, batch_idx  : 52, triplet_loss : 0.0
# epoch : 48, globaliter : 4709, batch_idx  : 53, triplet_loss : 0.0
# epoch : 48, globaliter : 4710, batch_idx  : 54, triplet_loss : 0.0
# epoch : 48, globaliter : 4711, batch_idx  : 55, triplet_loss : 0.0075827548280358315
# epoch : 48, globaliter : 4712, batch_idx  : 56, triplet_loss : 0.0013133995234966278
# epoch : 48, globaliter : 4713, batch_idx  : 57, triplet_loss : 0.0036085769534111023
# epoch : 48, globaliter : 4714, batch_idx  : 58, triplet_loss : 0.0
# epoch : 48, globaliter : 4715, batch_idx  : 59, triplet_loss : 0.0015084706246852875
# epoch : 48, globaliter : 4716, batch_idx  : 60, triplet_loss : 0.010995574295520782
# epoch : 48, globaliter : 4717, batch_idx  : 61, triplet_loss : 0.018177146092057228
# epoch : 48, globaliter : 4718, batch_idx  : 62, triplet_loss : 0.0
# epoch : 48, globaliter : 4719, batch_idx  : 63, triplet_loss : 0.0
# epoch : 48, globaliter : 4720, batch_idx  : 64, triplet_loss : 0.022047782316803932
# epoch : 48, globaliter : 4721, batch_idx  : 65, triplet_loss : 0.000991038978099823
# epoch : 48, globaliter : 4722, batch_idx  : 66, triplet_loss : 0.0002524927258491516
# epoch : 48, globaliter : 4723, batch_idx  : 67, triplet_loss : 0.0
# epoch : 48, globaliter : 4724, batch_idx  : 68, triplet_loss : 0.012789599597454071
# epoch : 48, globaliter : 4725, batch_idx  : 69, triplet_loss : 0.0
# epoch : 48, globaliter : 4726, batch_idx  : 70, triplet_loss : 0.0
# epoch : 48, globaliter : 4727, batch_idx  : 71, triplet_loss : 0.0
# epoch : 48, globaliter : 4728, batch_idx  : 72, triplet_loss : 0.002913577249273658
# epoch : 48, globaliter : 4729, batch_idx  : 73, triplet_loss : 0.00783050898462534
# epoch : 48, globaliter : 4730, batch_idx  : 74, triplet_loss : 0.0009861811995506287
# epoch : 48, globaliter : 4731, batch_idx  : 75, triplet_loss : 0.0029460133519023657
# epoch : 48, globaliter : 4732, batch_idx  : 76, triplet_loss : 0.01233861967921257
# epoch : 48, globaliter : 4733, batch_idx  : 77, triplet_loss : 0.0
# epoch : 48, globaliter : 4734, batch_idx  : 78, triplet_loss : 0.0
# epoch : 48, globaliter : 4735, batch_idx  : 79, triplet_loss : 0.0
# epoch : 48, globaliter : 4736, batch_idx  : 80, triplet_loss : 0.0001995973289012909
# epoch : 48, globaliter : 4737, batch_idx  : 81, triplet_loss : 0.015701774507761
# epoch : 48, globaliter : 4738, batch_idx  : 82, triplet_loss : 0.006376940757036209
# epoch : 48, globaliter : 4739, batch_idx  : 83, triplet_loss : 0.0
# epoch : 48, globaliter : 4740, batch_idx  : 84, triplet_loss : 0.0
# epoch : 48, globaliter : 4741, batch_idx  : 85, triplet_loss : 0.003752885852009058
# epoch : 48, globaliter : 4742, batch_idx  : 86, triplet_loss : 0.0
# epoch : 48, globaliter : 4743, batch_idx  : 87, triplet_loss : 0.0
# epoch : 48, globaliter : 4744, batch_idx  : 88, triplet_loss : 0.006526712328195572
# epoch : 48, globaliter : 4745, batch_idx  : 89, triplet_loss : 0.0
# epoch : 48, globaliter : 4746, batch_idx  : 90, triplet_loss : 0.0055823842994868755
# epoch : 48, globaliter : 4747, batch_idx  : 91, triplet_loss : 0.0019024846842512488
# epoch : 48, globaliter : 4748, batch_idx  : 92, triplet_loss : 0.0
# epoch : 48, globaliter : 4749, batch_idx  : 93, triplet_loss : 0.0015615373849868774
# epoch : 48, globaliter : 4750, batch_idx  : 94, triplet_loss : 0.0029624132439494133
# epoch : 48, globaliter : 4751, batch_idx  : 95, triplet_loss : 0.0
# epoch : 48, globaliter : 4752, batch_idx  : 96, triplet_loss : 0.006284974981099367
# epoch : 49, globaliter : 4753, batch_idx  : 0, triplet_loss : 0.0016472674906253815
# epoch : 49, globaliter : 4754, batch_idx  : 1, triplet_loss : 0.0
# epoch : 49, globaliter : 4755, batch_idx  : 2, triplet_loss : 0.0
# epoch : 49, globaliter : 4756, batch_idx  : 3, triplet_loss : 0.014868996106088161
# epoch : 49, globaliter : 4757, batch_idx  : 4, triplet_loss : 0.0
# epoch : 49, globaliter : 4758, batch_idx  : 5, triplet_loss : 0.006013491656631231
# epoch : 49, globaliter : 4759, batch_idx  : 6, triplet_loss : 0.0018541477620601654
# epoch : 49, globaliter : 4760, batch_idx  : 7, triplet_loss : 0.0
# epoch : 49, globaliter : 4761, batch_idx  : 8, triplet_loss : 0.0034036871511489153
# epoch : 49, globaliter : 4762, batch_idx  : 9, triplet_loss : 0.009229116141796112
# epoch : 49, globaliter : 4763, batch_idx  : 10, triplet_loss : 0.0
# epoch : 49, globaliter : 4764, batch_idx  : 11, triplet_loss : 0.002946762368083
# epoch : 49, globaliter : 4765, batch_idx  : 12, triplet_loss : 0.0
# epoch : 49, globaliter : 4766, batch_idx  : 13, triplet_loss : 0.0
# epoch : 49, globaliter : 4767, batch_idx  : 14, triplet_loss : 0.0012426301836967468
# epoch : 49, globaliter : 4768, batch_idx  : 15, triplet_loss : 0.02683887630701065
# epoch : 49, globaliter : 4769, batch_idx  : 16, triplet_loss : 0.006561965215951204
# epoch : 49, globaliter : 4770, batch_idx  : 17, triplet_loss : 0.0
# epoch : 49, globaliter : 4771, batch_idx  : 18, triplet_loss : 0.009834292344748974
# epoch : 49, globaliter : 4772, batch_idx  : 19, triplet_loss : 0.0
# epoch : 49, globaliter : 4773, batch_idx  : 20, triplet_loss : 0.0053940024226903915
# epoch : 49, globaliter : 4774, batch_idx  : 21, triplet_loss : 0.001172596588730812
# epoch : 49, globaliter : 4775, batch_idx  : 22, triplet_loss : 0.0013327226042747498
# epoch : 49, globaliter : 4776, batch_idx  : 23, triplet_loss : 0.0007243603467941284
# epoch : 49, globaliter : 4777, batch_idx  : 24, triplet_loss : 0.0
# epoch : 49, globaliter : 4778, batch_idx  : 25, triplet_loss : 0.003913423046469688
# epoch : 49, globaliter : 4779, batch_idx  : 26, triplet_loss : 0.0031133443117141724
# epoch : 49, globaliter : 4780, batch_idx  : 27, triplet_loss : 0.004709682893007994
# epoch : 49, globaliter : 4781, batch_idx  : 28, triplet_loss : 0.007649731822311878
# epoch : 49, globaliter : 4782, batch_idx  : 29, triplet_loss : 0.009186243638396263
# epoch : 49, globaliter : 4783, batch_idx  : 30, triplet_loss : 0.0008804388344287872
# epoch : 49, globaliter : 4784, batch_idx  : 31, triplet_loss : 0.0
# epoch : 49, globaliter : 4785, batch_idx  : 32, triplet_loss : 0.0
# epoch : 49, globaliter : 4786, batch_idx  : 33, triplet_loss : 0.0
# epoch : 49, globaliter : 4787, batch_idx  : 34, triplet_loss : 0.0
# epoch : 49, globaliter : 4788, batch_idx  : 35, triplet_loss : 0.0021605640649795532
# epoch : 49, globaliter : 4789, batch_idx  : 36, triplet_loss : 0.0
# epoch : 49, globaliter : 4790, batch_idx  : 37, triplet_loss : 0.006717313546687365
# epoch : 49, globaliter : 4791, batch_idx  : 38, triplet_loss : 0.0
# epoch : 49, globaliter : 4792, batch_idx  : 39, triplet_loss : 0.003937365487217903
# epoch : 49, globaliter : 4793, batch_idx  : 40, triplet_loss : 0.0031212233006954193
# epoch : 49, globaliter : 4794, batch_idx  : 41, triplet_loss : 0.0
# epoch : 49, globaliter : 4795, batch_idx  : 42, triplet_loss : 0.0
# epoch : 49, globaliter : 4796, batch_idx  : 43, triplet_loss : 0.0
# epoch : 49, globaliter : 4797, batch_idx  : 44, triplet_loss : 0.003987552132457495
# epoch : 49, globaliter : 4798, batch_idx  : 45, triplet_loss : 0.0011527501046657562
# epoch : 49, globaliter : 4799, batch_idx  : 46, triplet_loss : 0.0009241849184036255
# epoch : 49, globaliter : 4800, batch_idx  : 47, triplet_loss : 0.002302889944985509
# epoch : 49, globaliter : 4801, batch_idx  : 48, triplet_loss : 0.0018186811357736588
# epoch : 49, globaliter : 4802, batch_idx  : 49, triplet_loss : 0.0
# epoch : 49, globaliter : 4803, batch_idx  : 50, triplet_loss : 0.005644647870212793
# epoch : 49, globaliter : 4804, batch_idx  : 51, triplet_loss : 0.0
# epoch : 49, globaliter : 4805, batch_idx  : 52, triplet_loss : 0.0
# epoch : 49, globaliter : 4806, batch_idx  : 53, triplet_loss : 0.06637505441904068
# epoch : 49, globaliter : 4807, batch_idx  : 54, triplet_loss : 0.03405316546559334
# epoch : 49, globaliter : 4808, batch_idx  : 55, triplet_loss : 0.0
# epoch : 49, globaliter : 4809, batch_idx  : 56, triplet_loss : 0.003910863772034645
# epoch : 49, globaliter : 4810, batch_idx  : 57, triplet_loss : 0.0018201936036348343
# epoch : 49, globaliter : 4811, batch_idx  : 58, triplet_loss : 0.0
# epoch : 49, globaliter : 4812, batch_idx  : 59, triplet_loss : 0.0012777484953403473
# epoch : 49, globaliter : 4813, batch_idx  : 60, triplet_loss : 0.007700666785240173
# epoch : 49, globaliter : 4814, batch_idx  : 61, triplet_loss : 0.0
# epoch : 49, globaliter : 4815, batch_idx  : 62, triplet_loss : 0.00355452299118042
# epoch : 49, globaliter : 4816, batch_idx  : 63, triplet_loss : 0.006406179163604975
# epoch : 49, globaliter : 4817, batch_idx  : 64, triplet_loss : 0.04893878102302551
# epoch : 49, globaliter : 4818, batch_idx  : 65, triplet_loss : 0.0
# epoch : 49, globaliter : 4819, batch_idx  : 66, triplet_loss : 0.0641431212425232
# epoch : 49, globaliter : 4820, batch_idx  : 67, triplet_loss : 0.005729163996875286
# epoch : 49, globaliter : 4821, batch_idx  : 68, triplet_loss : 0.00014063715934753418
# epoch : 49, globaliter : 4822, batch_idx  : 69, triplet_loss : 0.0023056091740727425
# epoch : 49, globaliter : 4823, batch_idx  : 70, triplet_loss : 0.0
# epoch : 49, globaliter : 4824, batch_idx  : 71, triplet_loss : 0.008363918401300907
# epoch : 49, globaliter : 4825, batch_idx  : 72, triplet_loss : 0.010678626596927643
# epoch : 49, globaliter : 4826, batch_idx  : 73, triplet_loss : 0.013169650919735432
# epoch : 49, globaliter : 4827, batch_idx  : 74, triplet_loss : 0.035581424832344055
# epoch : 49, globaliter : 4828, batch_idx  : 75, triplet_loss : 0.000884711742401123
# epoch : 49, globaliter : 4829, batch_idx  : 76, triplet_loss : 0.009908124804496765
# epoch : 49, globaliter : 4830, batch_idx  : 77, triplet_loss : 0.0
# epoch : 49, globaliter : 4831, batch_idx  : 78, triplet_loss : 0.0012780427932739258
# epoch : 49, globaliter : 4832, batch_idx  : 79, triplet_loss : 0.0
# epoch : 49, globaliter : 4833, batch_idx  : 80, triplet_loss : 0.008194541558623314
# epoch : 49, globaliter : 4834, batch_idx  : 81, triplet_loss : 0.0
# epoch : 49, globaliter : 4835, batch_idx  : 82, triplet_loss : 0.0
# epoch : 49, globaliter : 4836, batch_idx  : 83, triplet_loss : 0.0025822848547250032
# epoch : 49, globaliter : 4837, batch_idx  : 84, triplet_loss : 0.002374023199081421
# epoch : 49, globaliter : 4838, batch_idx  : 85, triplet_loss : 0.03493102267384529
# epoch : 49, globaliter : 4839, batch_idx  : 86, triplet_loss : 0.010796277783811092
# epoch : 49, globaliter : 4840, batch_idx  : 87, triplet_loss : 0.00891834869980812
# epoch : 49, globaliter : 4841, batch_idx  : 88, triplet_loss : 0.0
# epoch : 49, globaliter : 4842, batch_idx  : 89, triplet_loss : 0.0
# epoch : 49, globaliter : 4843, batch_idx  : 90, triplet_loss : 0.008373674005270004
# epoch : 49, globaliter : 4844, batch_idx  : 91, triplet_loss : 0.004271022509783506
# epoch : 49, globaliter : 4845, batch_idx  : 92, triplet_loss : 0.005060996860265732
# epoch : 49, globaliter : 4846, batch_idx  : 93, triplet_loss : 0.0
# epoch : 49, globaliter : 4847, batch_idx  : 94, triplet_loss : 0.0
# epoch : 49, globaliter : 4848, batch_idx  : 95, triplet_loss : 0.003099027555435896
# epoch : 49, globaliter : 4849, batch_idx  : 96, triplet_loss : 0.00559585727751255

# %%
# !wget -O model_47.pt "https://www.dropbox.com/s/g5nwt0do351huc2/model_47.pt?dl=1"
# !wget -O model_48.pt "https://www.dropbox.com/s/86qev1vgg545ee4/model_48.pt?dl=1"
# !wget -O model_49.pt "https://www.dropbox.com/s/obceyvw3d40rsxo/model_49.pt?dl=1"
# Out:
# --2022-01-13 15:37:55--  https://www.dropbox.com/s/g5nwt0do351huc2/model_47.pt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/g5nwt0do351huc2/model_47.pt [following]
# --2022-01-13 15:37:57--  https://www.dropbox.com/s/dl/g5nwt0do351huc2/model_47.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com/cd/0/get/BdvbUkmdxu9RlgTNyVcuFqbhK5J58zmFvWJeJJCv1XZO7BagRtndYuytVMgY9uzYCTu4taMISxcKVxRkOEX0xsGPI2C3MHBS4ZaleP1TafJP1GNe3xbcSwDaa5YnAfIEaHXbE9Y6DLD-jlC5vhj1Ge8L/file?dl=1# [following]
# --2022-01-13 15:37:57--  https://uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com/cd/0/get/BdvbUkmdxu9RlgTNyVcuFqbhK5J58zmFvWJeJJCv1XZO7BagRtndYuytVMgY9uzYCTu4taMISxcKVxRkOEX0xsGPI2C3MHBS4ZaleP1TafJP1GNe3xbcSwDaa5YnAfIEaHXbE9Y6DLD-jlC5vhj1Ge8L/file?dl=1
# Resolving uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com (uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com (uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44791031 (43M) [application/binary]
# Saving to: ‘model_47.pt’
#
# model_47.pt         100%[===================>]  42,72M  7,09MB/s    in 5,9s
#
# 2022-01-13 15:38:04 (7,24 MB/s) - ‘model_47.pt’ saved [44791031/44791031]
#
# --2022-01-13 15:38:05--  https://www.dropbox.com/s/86qev1vgg545ee4/model_48.pt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/86qev1vgg545ee4/model_48.pt [following]
# --2022-01-13 15:38:05--  https://www.dropbox.com/s/dl/86qev1vgg545ee4/model_48.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com/cd/0/get/BduK9x4EVEXojWlopIeOKA_IhVunvP9YBdkEzOhgtODMoXfJsk2JKki7NBNDsHSACyjCaDq3bzWXaBAsl4B_GXTmuWyqswmVjCBVilXHYjZHnhfYD39xJZAKoQI5AhF8J1RHmvgGm4IdNl1Xo6YFZW_G/file?dl=1# [following]
# --2022-01-13 15:38:06--  https://uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com/cd/0/get/BduK9x4EVEXojWlopIeOKA_IhVunvP9YBdkEzOhgtODMoXfJsk2JKki7NBNDsHSACyjCaDq3bzWXaBAsl4B_GXTmuWyqswmVjCBVilXHYjZHnhfYD39xJZAKoQI5AhF8J1RHmvgGm4IdNl1Xo6YFZW_G/file?dl=1
# Resolving uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com (uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com (uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44791031 (43M) [application/binary]
# Saving to: ‘model_48.pt’
#
# model_48.pt         100%[===================>]  42,72M  8,38MB/s    in 5,5s
#
# 2022-01-13 15:38:12 (7,78 MB/s) - ‘model_48.pt’ saved [44791031/44791031]
#
# --2022-01-13 15:38:13--  https://www.dropbox.com/s/obceyvw3d40rsxo/model_49.pt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/obceyvw3d40rsxo/model_49.pt [following]
# --2022-01-13 15:38:13--  https://www.dropbox.com/s/dl/obceyvw3d40rsxo/model_49.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com/cd/0/get/BdscPhRsygA28apVR9Td-20_aKCdydax4ypeP1kuLLCEHR1T2w1Jg44Z0-s7CQS4t2wBfEHKhpAgx2nNihb3Dwp2Z98Ob_awC10He_vECX9jthOxYvqTKcyz4oGWys9atyEHv2w62HxRknlYv4Bx_--7/file?dl=1# [following]
# --2022-01-13 15:38:14--  https://uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com/cd/0/get/BdscPhRsygA28apVR9Td-20_aKCdydax4ypeP1kuLLCEHR1T2w1Jg44Z0-s7CQS4t2wBfEHKhpAgx2nNihb3Dwp2Z98Ob_awC10He_vECX9jthOxYvqTKcyz4oGWys9atyEHv2w62HxRknlYv4Bx_--7/file?dl=1
# Resolving uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com (uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com (uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44791031 (43M) [application/binary]
# Saving to: ‘model_49.pt’
#
# model_49.pt         100%[===================>]  42,72M  7,18MB/s    in 6,0s
#
# 2022-01-13 15:38:21 (7,17 MB/s) - ‘model_49.pt’ saved [44791031/44791031]

# %%
state_dict = torch.load('./model_46.pt')
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
out_train_image = model(bef_train_image.cuda())
X_train = out_train_image
Y_train = bef_train_label

# %%
for test_image,test_label in test_data_loader :  
  output_test = model(test_image.cuda())
  X_test = output_test
  Y_test = test_label

# %%
from PIL import Image
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)
import torchvision.transforms.functional as Function
from IPython.display import display
from time import time
from matplotlib import offsetbox
from sklearn.neighbors import DistanceMetric
# %matplotlib inline

def plot_embedding(X, y_t, title=None):

    y = y_t.numpy()
    
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    plt.figure()
    for i in range(X.shape[0]):
      if i == 776 :
        plt.text(X[i, 0], X[i, 1], str(y[i]),
               color='black',
               fontdict={'weight': 'bold', 'size': 30})
      else :
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=plt.cm.Set1(y[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)

# %%
check_index = 10

# %%
test_image.shape
test_label.shape
# Out:
# torch.Size([98])

# %%
image_query = X_test[check_index].view(1,-1)
label_query = Y_test[check_index].view(1)
X_total= torch.cat([X_train, image_query], dim=0)
Y_total= torch.cat([Y_train, label_query], dim=0)

test_img = Function.to_pil_image(test_image[check_index])
print('Test image : {}'.format(test_label[check_index].item()))
display(test_img)

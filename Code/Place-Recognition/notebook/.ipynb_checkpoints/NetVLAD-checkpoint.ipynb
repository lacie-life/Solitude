# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import tensorflow as tf

from torch.autograd import Variable
from torchvision.models import resnet18

from tensorflow import keras
from keras.preprocessing import image

import PIL
import torch
import torchvision

import matplotlib.pyplot as plt
from sklearn import svm, datasets, metrics

torch.manual_seed(777)

# %%
# !pip install tensorboardcolab
from tensorboardcolab import TensorBoardColab
tb = TensorBoardColab()

# %%
class NetVLAD(nn.Module):
    """NetVLAD layer implementation"""

    def __init__(self, num_clusters=6, dim=128, alpha=100.0,
                 normalize_input=True):
        """
        Args:
            num_clusters : int
                The number of clusters
            dim : int
                Dimension of descriptors
            alpha : float
                Parameter of initialization. Larger value is harder assignment.
            normalize_input : bool
                If true, descriptor-wise L2 normalization is applied to input.
        """
        super(NetVLAD, self).__init__()
        self.num_clusters = num_clusters
        self.dim = dim
        self.alpha = alpha
        self.normalize_input = normalize_input
        self.conv = nn.Conv2d(dim, num_clusters, kernel_size=(1, 1), bias=True)
        self.centroids = nn.Parameter(torch.rand(num_clusters, dim))
        self._init_params()

    def _init_params(self):
        self.conv.weight = nn.Parameter(
            (2.0 * self.alpha * self.centroids).unsqueeze(-1).unsqueeze(-1)
        )
        self.conv.bias = nn.Parameter(
            - self.alpha * self.centroids.norm(dim=1)
        )

    def forward(self, x):
        N, C = x.shape[:2]

        if self.normalize_input:
            x = F.normalize(x, p=2, dim=1)  # across descriptor dim

        # soft-assignment
        soft_assign = self.conv(x).view(N, self.num_clusters, -1)
        soft_assign = F.softmax(soft_assign, dim=1)

        x_flatten = x.view(N, C, -1)
        
        # calculate residuals to each clusters
        residual = x_flatten.expand(self.num_clusters, -1, -1, -1).permute(1, 0, 2, 3) - \
            self.centroids.expand(x_flatten.size(-1), -1, -1).permute(1, 2, 0).unsqueeze(0)
        residual *= soft_assign.unsqueeze(2)
        vlad = residual.sum(dim=-1)

        vlad = F.normalize(vlad, p=2, dim=2)  # intra-normalization
        vlad = vlad.view(x.size(0), -1)  # flatten
        vlad = F.normalize(vlad, p=2, dim=1)  # L2 normalize

        return vlad

# %%
class EmbedNet(nn.Module):
    def __init__(self, base_model, net_vlad):
        super(EmbedNet, self).__init__()
        self.base_model = base_model
        self.net_vlad = net_vlad

    def forward(self, x):
        x = self.base_model(x)
        embedded_x = self.net_vlad(x)
        return embedded_x
      
class TripletNet(nn.Module):
    def __init__(self, embed_net):
        super(TripletNet, self).__init__()
        self.embed_net = embed_net

    def forward(self, a, p, n):
        embedded_a = self.embed_net(a)
        embedded_p = self.embed_net(p)
        embedded_n = self.embed_net(n)
        return embedded_a, embedded_p, embedded_n

    def feature_extract(self, x):
        return self.embed_net(x)

# %%
class HardTripletLoss(nn.Module):
    """Hard/Hardest Triplet Loss
    (pytorch implementation of https://omoindrot.github.io/triplet-loss)
    For each anchor, we get the hardest positive and hardest negative to form a triplet.
    """
    def __init__(self, margin=0.1, hardest=False, squared=False):
        """
        Args:
            margin: margin for triplet loss
            hardest: If true, loss is considered only hardest triplets.
            squared: If true, output is the pairwise squared euclidean distance matrix.
                If false, output is the pairwise euclidean distance matrix.
        """
        super(HardTripletLoss, self).__init__()
        self.margin = margin
        self.hardest = hardest
        self.squared = squared

    def forward(self, embeddings, labels):
        """
        Args:
            labels: labels of the batch, of size (batch_size,)
            embeddings: tensor of shape (batch_size, embed_dim)
        Returns:
            triplet_loss: scalar tensor containing the triplet loss
        """
        pairwise_dist = _pairwise_distance(embeddings, squared=self.squared)

        if self.hardest:
            # Get the hardest positive pairs
            mask_anchor_positive = _get_anchor_positive_triplet_mask(labels).float()
            valid_positive_dist = pairwise_dist * mask_anchor_positive
            hardest_positive_dist, _ = torch.max(valid_positive_dist, dim=1, keepdim=True)

            # Get the hardest negative pairs
            mask_anchor_negative = _get_anchor_negative_triplet_mask(labels).float()
            max_anchor_negative_dist, _ = torch.max(pairwise_dist, dim=1, keepdim=True)
            anchor_negative_dist = pairwise_dist + max_anchor_negative_dist * (
                    1.0 - mask_anchor_negative)
            hardest_negative_dist, _ = torch.min(anchor_negative_dist, dim=1, keepdim=True)

            # Combine biggest d(a, p) and smallest d(a, n) into final triplet loss
            triplet_loss = F.relu(hardest_positive_dist - hardest_negative_dist + 0.1)
            triplet_loss = torch.mean(triplet_loss)
        else:
            anc_pos_dist = pairwise_dist.unsqueeze(dim=2)
            anc_neg_dist = pairwise_dist.unsqueeze(dim=1)

            # Compute a 3D tensor of size (batch_size, batch_size, batch_size)
            # triplet_loss[i, j, k] will contain the triplet loss of anc=i, pos=j, neg=k
            # Uses broadcasting where the 1st argument has shape (batch_size, batch_size, 1)
            # and the 2nd (batch_size, 1, batch_size)
            loss = anc_pos_dist - anc_neg_dist + self.margin

            mask = _get_triplet_mask(labels).float()
            triplet_loss = loss * mask

            # Remove negative losses (i.e. the easy triplets)
            triplet_loss = F.relu(triplet_loss)

            # Count number of hard triplets (where triplet_loss > 0)
            hard_triplets = torch.gt(triplet_loss, 1e-16).float()
            num_hard_triplets = torch.sum(hard_triplets)

            triplet_loss = torch.sum(triplet_loss) / (num_hard_triplets + 1e-16)

        return triplet_loss


def _pairwise_distance(x, squared=False, eps=1e-16):
    # Compute the 2D matrix of distances between all the embeddings.

    cor_mat = torch.matmul(x, x.t())
    norm_mat = cor_mat.diag()
    distances = norm_mat.unsqueeze(1) - 2 * cor_mat + norm_mat.unsqueeze(0)
    distances = F.relu(distances)

    if not squared:
        mask = torch.eq(distances, 0.0).float()
        distances = distances + mask * eps
        distances = torch.sqrt(distances)
        distances = distances * (1.0 - mask)

    return distances


def _get_anchor_positive_triplet_mask(labels):
    # Return a 2D mask where mask[a, p] is True iff a and p are distinct and have same label.

    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    indices_not_equal = torch.eye(labels.shape[0]).to(device).byte() ^ 1

    # Check if labels[i] == labels[j]
    labels_equal = torch.unsqueeze(labels, 0) == torch.unsqueeze(labels, 1)

    mask = indices_not_equal * labels_equal

    return mask


def _get_anchor_negative_triplet_mask(labels):
    # Return a 2D mask where mask[a, n] is True iff a and n have distinct labels.

    # Check if labels[i] != labels[k]
    labels_equal = torch.unsqueeze(labels, 0) == torch.unsqueeze(labels, 1)
    mask = labels_equal ^ 1

    return mask


def _get_triplet_mask(labels):
    """Return a 3D mask where mask[a, p, n] is True iff the triplet (a, p, n) is valid.
    A triplet (i, j, k) is valid if:
        - i, j, k are distinct
        - labels[i] == labels[j] and labels[i] != labels[k]
    """
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

    # Check that i, j and k are distinct
    indices_not_same = torch.eye(labels.shape[0]).to(device).byte() ^ 1
    i_not_equal_j = torch.unsqueeze(indices_not_same, 2)
    i_not_equal_k = torch.unsqueeze(indices_not_same, 1)
    j_not_equal_k = torch.unsqueeze(indices_not_same, 0)
    distinct_indices = i_not_equal_j * i_not_equal_k * j_not_equal_k

    # Check if labels[i] == labels[j] and labels[i] != labels[k]
    label_equal = torch.eq(torch.unsqueeze(labels, 0), torch.unsqueeze(labels, 1))
    i_equal_j = torch.unsqueeze(label_equal, 2)
    i_equal_k = torch.unsqueeze(label_equal, 1)
    valid_labels = i_equal_j * (~i_equal_k)

    mask = distinct_indices * valid_labels   # Combine the two masks

    return mask

# %%
# Discard layers at the end of base network
encoder = resnet18(pretrained=True)
base_model = nn.Sequential(
    encoder.conv1,
    encoder.bn1,
    encoder.relu,
    encoder.maxpool,
    encoder.layer1,
    encoder.layer2,
    encoder.layer3,
    encoder.layer4,
)
dim = list(base_model.parameters())[-1].shape[0]  # last channels (512)

# Define model for embedding
net_vlad = NetVLAD(num_clusters=6, dim=dim, alpha=1.0)
model = EmbedNet(base_model, net_vlad).cuda()

# %%
# Define loss
criterion = HardTripletLoss(margin=0.1).cuda()
epochs = 50
optimizer = torch.optim.SGD(model.parameters(), lr=0.1)

# %%
transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((128,128)),               
    torchvision.transforms.ToTensor()
    
])

bef_train_imagenet_data = torchvision.datasets.ImageFolder('/home/jun/Data/F4-E5/train', transform=transforms)
bef_train_data_loader = torch.utils.data.DataLoader(bef_train_imagenet_data,
                                          batch_size=776,
                                          shuffle=False,
                                          num_workers=0)

# %%
for bef_train_image,bef_train_label in bef_train_data_loader :
#     print(bef_train_image)
#     print(bef_train_lable)
    bef_train_image = bef_train_image
    bef_train_label = bef_train_label

# %%
train_imagenet_data = torchvision.datasets.ImageFolder('/home/jun/Data/F4-E5/train', transform=transforms)
train_data_loader = torch.utils.data.DataLoader(train_imagenet_data,
                                          batch_size=8,
                                          shuffle=True,
                                          num_workers=0)
test_imagenet_data = torchvision.datasets.ImageFolder('/home/jun/Data/F4-E5/test', transform=transforms)
test_data_loader = torch.utils.data.DataLoader(test_imagenet_data,
                                          shuffle=False,
                                          batch_size=100,
                                          num_workers=0)

# %%
globaliter = 0

for epoch in range(epochs):
  for batch_idx, (train_image,train_label) in enumerate(train_data_loader) :
    output_train = model(train_image.cuda())
    triplet_loss = criterion(output_train, train_label.cuda())
    optimizer.zero_grad()
    triplet_loss.backward(retain_graph=True)
    optimizer.step()
    # This is where I'm recording to Tensorboard
    # tb.save_value('Train Loss', 'train_loss', globaliter, triplet_loss.item())
    print('epoch : {}, globaliter : {}, batch_idx  : {}, triplet_loss : {}'.format(epoch,globaliter,batch_idx,triplet_loss.item()))
    globaliter += 1
  model_save_name = 'model_{:02d}.pt'.format(epoch)
  path = F"./{model_save_name}" 
  torch.save(model.state_dict(), path)
# Out:
# epoch : 0, globaliter : 0, batch_idx  : 0, triplet_loss : 0.0996098741889
# epoch : 0, globaliter : 1, batch_idx  : 1, triplet_loss : 0.09398002177476883
# epoch : 0, globaliter : 2, batch_idx  : 2, triplet_loss : 0.09694953262805939
# epoch : 0, globaliter : 3, batch_idx  : 3, triplet_loss : 0.09913714975118637
# epoch : 0, globaliter : 4, batch_idx  : 4, triplet_loss : 0.0979781374335289
# epoch : 0, globaliter : 5, batch_idx  : 5, triplet_loss : 0.09499441087245941
# epoch : 0, globaliter : 6, batch_idx  : 6, triplet_loss : 0.09755291044712067
# epoch : 0, globaliter : 7, batch_idx  : 7, triplet_loss : 0.09999975562095642
# epoch : 0, globaliter : 8, batch_idx  : 8, triplet_loss : 0.097816102206707
# epoch : 0, globaliter : 9, batch_idx  : 9, triplet_loss : 0.09626775979995728
# epoch : 0, globaliter : 10, batch_idx  : 10, triplet_loss : 0.09813741594552994
# epoch : 0, globaliter : 11, batch_idx  : 11, triplet_loss : 0.09918225556612015
# epoch : 0, globaliter : 12, batch_idx  : 12, triplet_loss : 0.09829655289649963
# epoch : 0, globaliter : 13, batch_idx  : 13, triplet_loss : 0.09716682881116867
# epoch : 0, globaliter : 14, batch_idx  : 14, triplet_loss : 0.0955202579498291
# epoch : 0, globaliter : 15, batch_idx  : 15, triplet_loss : 0.09765258431434631
# epoch : 0, globaliter : 16, batch_idx  : 16, triplet_loss : 0.09591332077980042
# epoch : 0, globaliter : 17, batch_idx  : 17, triplet_loss : 0.09864392131567001
# epoch : 0, globaliter : 18, batch_idx  : 18, triplet_loss : 0.09662286937236786
# epoch : 0, globaliter : 19, batch_idx  : 19, triplet_loss : 0.09958931803703308
# epoch : 0, globaliter : 20, batch_idx  : 20, triplet_loss : 0.09905161708593369
# epoch : 0, globaliter : 21, batch_idx  : 21, triplet_loss : 0.09865444898605347
# epoch : 0, globaliter : 22, batch_idx  : 22, triplet_loss : 0.0991707444190979
# epoch : 0, globaliter : 23, batch_idx  : 23, triplet_loss : 0.09724504500627518
# epoch : 0, globaliter : 24, batch_idx  : 24, triplet_loss : 0.09659776836633682
# epoch : 0, globaliter : 25, batch_idx  : 25, triplet_loss : 0.0981169044971466
# epoch : 0, globaliter : 26, batch_idx  : 26, triplet_loss : 0.09718167036771774
# epoch : 0, globaliter : 27, batch_idx  : 27, triplet_loss : 0.09458845853805542
# epoch : 0, globaliter : 28, batch_idx  : 28, triplet_loss : 0.09793596714735031
# epoch : 0, globaliter : 29, batch_idx  : 29, triplet_loss : 0.09925263375043869
# epoch : 0, globaliter : 30, batch_idx  : 30, triplet_loss : 0.09737291932106018
# epoch : 0, globaliter : 31, batch_idx  : 31, triplet_loss : 0.10001511871814728
# epoch : 0, globaliter : 32, batch_idx  : 32, triplet_loss : 0.09872779995203018
# epoch : 0, globaliter : 33, batch_idx  : 33, triplet_loss : 0.09678403288125992
# epoch : 0, globaliter : 34, batch_idx  : 34, triplet_loss : 0.09800631552934647
# epoch : 0, globaliter : 35, batch_idx  : 35, triplet_loss : 0.09611739963293076
# epoch : 0, globaliter : 36, batch_idx  : 36, triplet_loss : 0.09890401363372803
# epoch : 0, globaliter : 37, batch_idx  : 37, triplet_loss : 0.0969846248626709
# epoch : 0, globaliter : 38, batch_idx  : 38, triplet_loss : 0.09764482080936432
# epoch : 0, globaliter : 39, batch_idx  : 39, triplet_loss : 0.09881642460823059
# epoch : 0, globaliter : 40, batch_idx  : 40, triplet_loss : 0.09875122457742691
# epoch : 0, globaliter : 41, batch_idx  : 41, triplet_loss : 0.09598764032125473
# epoch : 0, globaliter : 42, batch_idx  : 42, triplet_loss : 0.09851603955030441
# epoch : 0, globaliter : 43, batch_idx  : 43, triplet_loss : 0.0
# epoch : 1, globaliter : 44, batch_idx  : 0, triplet_loss : 0.09846175462007523
# epoch : 1, globaliter : 45, batch_idx  : 1, triplet_loss : 0.09515150636434555
# epoch : 1, globaliter : 46, batch_idx  : 2, triplet_loss : 0.09820295870304108
# epoch : 1, globaliter : 47, batch_idx  : 3, triplet_loss : 0.09874716401100159
# epoch : 1, globaliter : 48, batch_idx  : 4, triplet_loss : 0.09954548627138138
# epoch : 1, globaliter : 49, batch_idx  : 5, triplet_loss : 0.09492095559835434
# epoch : 1, globaliter : 50, batch_idx  : 6, triplet_loss : 0.09774210304021835
# epoch : 1, globaliter : 51, batch_idx  : 7, triplet_loss : 0.09768399596214294
# epoch : 1, globaliter : 52, batch_idx  : 8, triplet_loss : 0.09840686619281769
# epoch : 1, globaliter : 53, batch_idx  : 9, triplet_loss : 0.0945952758193016
# epoch : 1, globaliter : 54, batch_idx  : 10, triplet_loss : 0.0980938971042633
# epoch : 1, globaliter : 55, batch_idx  : 11, triplet_loss : 0.09874773025512695
# epoch : 1, globaliter : 56, batch_idx  : 12, triplet_loss : 0.09728299826383591
# epoch : 1, globaliter : 57, batch_idx  : 13, triplet_loss : 0.09565366059541702
# epoch : 1, globaliter : 58, batch_idx  : 14, triplet_loss : 0.10084554553031921
# epoch : 1, globaliter : 59, batch_idx  : 15, triplet_loss : 0.09812421351671219
# epoch : 1, globaliter : 60, batch_idx  : 16, triplet_loss : 0.09777320921421051
# epoch : 1, globaliter : 61, batch_idx  : 17, triplet_loss : 0.09669876098632812
# epoch : 1, globaliter : 62, batch_idx  : 18, triplet_loss : 0.09651116281747818
# epoch : 1, globaliter : 63, batch_idx  : 19, triplet_loss : 0.0978178083896637
# epoch : 1, globaliter : 64, batch_idx  : 20, triplet_loss : 0.09663421660661697
# epoch : 1, globaliter : 65, batch_idx  : 21, triplet_loss : 0.09553185105323792
# epoch : 1, globaliter : 66, batch_idx  : 22, triplet_loss : 0.0959775447845459
# epoch : 1, globaliter : 67, batch_idx  : 23, triplet_loss : 0.0979851633310318
# epoch : 1, globaliter : 68, batch_idx  : 24, triplet_loss : 0.09976857155561447
# epoch : 1, globaliter : 69, batch_idx  : 25, triplet_loss : 0.09816909581422806
# epoch : 1, globaliter : 70, batch_idx  : 26, triplet_loss : 0.09943140298128128
# epoch : 1, globaliter : 71, batch_idx  : 27, triplet_loss : 0.09757812321186066
# epoch : 1, globaliter : 72, batch_idx  : 28, triplet_loss : 0.09611227363348007
# epoch : 1, globaliter : 73, batch_idx  : 29, triplet_loss : 0.09797016531229019
# epoch : 1, globaliter : 74, batch_idx  : 30, triplet_loss : 0.09640525281429291
# epoch : 1, globaliter : 75, batch_idx  : 31, triplet_loss : 0.0964222401380539
# epoch : 1, globaliter : 76, batch_idx  : 32, triplet_loss : 0.09477514773607254
# epoch : 1, globaliter : 77, batch_idx  : 33, triplet_loss : 0.09927961230278015
# epoch : 1, globaliter : 78, batch_idx  : 34, triplet_loss : 0.09652147442102432
# epoch : 1, globaliter : 79, batch_idx  : 35, triplet_loss : 0.09915531426668167
# epoch : 1, globaliter : 80, batch_idx  : 36, triplet_loss : 0.09708636999130249
# epoch : 1, globaliter : 81, batch_idx  : 37, triplet_loss : 0.09684135764837265
# epoch : 1, globaliter : 82, batch_idx  : 38, triplet_loss : 0.0962269976735115
# epoch : 1, globaliter : 83, batch_idx  : 39, triplet_loss : 0.0945117324590683
# epoch : 1, globaliter : 84, batch_idx  : 40, triplet_loss : 0.09586489200592041
# epoch : 1, globaliter : 85, batch_idx  : 41, triplet_loss : 0.09836246818304062
# epoch : 1, globaliter : 86, batch_idx  : 42, triplet_loss : 0.09453588724136353
# epoch : 1, globaliter : 87, batch_idx  : 43, triplet_loss : 0.0
# epoch : 2, globaliter : 88, batch_idx  : 0, triplet_loss : 0.09456376731395721
# epoch : 2, globaliter : 89, batch_idx  : 1, triplet_loss : 0.09692307561635971
# epoch : 2, globaliter : 90, batch_idx  : 2, triplet_loss : 0.09578102082014084
# epoch : 2, globaliter : 91, batch_idx  : 3, triplet_loss : 0.09786605089902878
# epoch : 2, globaliter : 92, batch_idx  : 4, triplet_loss : 0.09734684973955154
# epoch : 2, globaliter : 93, batch_idx  : 5, triplet_loss : 0.0970136746764183
# epoch : 2, globaliter : 94, batch_idx  : 6, triplet_loss : 0.09581629931926727
# epoch : 2, globaliter : 95, batch_idx  : 7, triplet_loss : 0.09556259214878082
# epoch : 2, globaliter : 96, batch_idx  : 8, triplet_loss : 0.09313444048166275
# epoch : 2, globaliter : 97, batch_idx  : 9, triplet_loss : 0.09580066800117493
# epoch : 2, globaliter : 98, batch_idx  : 10, triplet_loss : 0.09838754683732986
# epoch : 2, globaliter : 99, batch_idx  : 11, triplet_loss : 0.09383337199687958
# epoch : 2, globaliter : 100, batch_idx  : 12, triplet_loss : 0.09762559086084366
# epoch : 2, globaliter : 101, batch_idx  : 13, triplet_loss : 0.09106649458408356
# epoch : 2, globaliter : 102, batch_idx  : 14, triplet_loss : 0.09827295690774918
# epoch : 2, globaliter : 103, batch_idx  : 15, triplet_loss : 0.09228697419166565
# epoch : 2, globaliter : 104, batch_idx  : 16, triplet_loss : 0.09808814525604248
# epoch : 2, globaliter : 105, batch_idx  : 17, triplet_loss : 0.09499992430210114
# epoch : 2, globaliter : 106, batch_idx  : 18, triplet_loss : 0.09564033895730972
# epoch : 2, globaliter : 107, batch_idx  : 19, triplet_loss : 0.0967225581407547
# epoch : 2, globaliter : 108, batch_idx  : 20, triplet_loss : 0.09902751445770264
# epoch : 2, globaliter : 109, batch_idx  : 21, triplet_loss : 0.09294738620519638
# epoch : 2, globaliter : 110, batch_idx  : 22, triplet_loss : 0.09717116504907608
# epoch : 2, globaliter : 111, batch_idx  : 23, triplet_loss : 0.09516163170337677
# epoch : 2, globaliter : 112, batch_idx  : 24, triplet_loss : 0.09411732852458954
# epoch : 2, globaliter : 113, batch_idx  : 25, triplet_loss : 0.09528125077486038
# epoch : 2, globaliter : 114, batch_idx  : 26, triplet_loss : 0.09801419079303741
# epoch : 2, globaliter : 115, batch_idx  : 27, triplet_loss : 0.09266623854637146
# epoch : 2, globaliter : 116, batch_idx  : 28, triplet_loss : 0.0941477045416832
# epoch : 2, globaliter : 117, batch_idx  : 29, triplet_loss : 0.08963026851415634
# epoch : 2, globaliter : 118, batch_idx  : 30, triplet_loss : 0.09646476805210114
# epoch : 2, globaliter : 119, batch_idx  : 31, triplet_loss : 0.0941697433590889
# epoch : 2, globaliter : 120, batch_idx  : 32, triplet_loss : 0.09371338039636612
# epoch : 2, globaliter : 121, batch_idx  : 33, triplet_loss : 0.09298624098300934
# epoch : 2, globaliter : 122, batch_idx  : 34, triplet_loss : 0.09424220770597458
# epoch : 2, globaliter : 123, batch_idx  : 35, triplet_loss : 0.09361150115728378
# epoch : 2, globaliter : 124, batch_idx  : 36, triplet_loss : 0.09281112253665924
# epoch : 2, globaliter : 125, batch_idx  : 37, triplet_loss : 0.09579279273748398
# epoch : 2, globaliter : 126, batch_idx  : 38, triplet_loss : 0.09456738084554672
# epoch : 2, globaliter : 127, batch_idx  : 39, triplet_loss : 0.0980212539434433
# epoch : 2, globaliter : 128, batch_idx  : 40, triplet_loss : 0.09555253386497498
# epoch : 2, globaliter : 129, batch_idx  : 41, triplet_loss : 0.09689170122146606
# epoch : 2, globaliter : 130, batch_idx  : 42, triplet_loss : 0.09684981405735016
# epoch : 2, globaliter : 131, batch_idx  : 43, triplet_loss : 0.0
# epoch : 3, globaliter : 132, batch_idx  : 0, triplet_loss : 0.09493671357631683
# epoch : 3, globaliter : 133, batch_idx  : 1, triplet_loss : 0.09772617369890213
# epoch : 3, globaliter : 134, batch_idx  : 2, triplet_loss : 0.0997772365808487
# epoch : 3, globaliter : 135, batch_idx  : 3, triplet_loss : 0.09163123369216919
# epoch : 3, globaliter : 136, batch_idx  : 4, triplet_loss : 0.09504425525665283
# epoch : 3, globaliter : 137, batch_idx  : 5, triplet_loss : 0.09811097383499146
# epoch : 3, globaliter : 138, batch_idx  : 6, triplet_loss : 0.09783220291137695
# epoch : 3, globaliter : 139, batch_idx  : 7, triplet_loss : 0.09204258769750595
# epoch : 3, globaliter : 140, batch_idx  : 8, triplet_loss : 0.09839437901973724
# epoch : 3, globaliter : 141, batch_idx  : 9, triplet_loss : 0.09374093264341354
# epoch : 3, globaliter : 142, batch_idx  : 10, triplet_loss : 0.09649880975484848
# epoch : 3, globaliter : 143, batch_idx  : 11, triplet_loss : 0.09358208626508713
# epoch : 3, globaliter : 144, batch_idx  : 12, triplet_loss : 0.09217227250337601
# epoch : 3, globaliter : 145, batch_idx  : 13, triplet_loss : 0.09743466973304749
# epoch : 3, globaliter : 146, batch_idx  : 14, triplet_loss : 0.09024230390787125
# epoch : 3, globaliter : 147, batch_idx  : 15, triplet_loss : 0.09247045964002609
# epoch : 3, globaliter : 148, batch_idx  : 16, triplet_loss : 0.09049629420042038
# epoch : 3, globaliter : 149, batch_idx  : 17, triplet_loss : 0.0946110337972641
# epoch : 3, globaliter : 150, batch_idx  : 18, triplet_loss : 0.09374428540468216
# epoch : 3, globaliter : 151, batch_idx  : 19, triplet_loss : 0.09504470229148865
# epoch : 3, globaliter : 152, batch_idx  : 20, triplet_loss : 0.0940231904387474
# epoch : 3, globaliter : 153, batch_idx  : 21, triplet_loss : 0.092022605240345
# epoch : 3, globaliter : 154, batch_idx  : 22, triplet_loss : 0.09665071219205856
# epoch : 3, globaliter : 155, batch_idx  : 23, triplet_loss : 0.09658873081207275
# epoch : 3, globaliter : 156, batch_idx  : 24, triplet_loss : 0.08661802113056183
# epoch : 3, globaliter : 157, batch_idx  : 25, triplet_loss : 0.09627924859523773
# epoch : 3, globaliter : 158, batch_idx  : 26, triplet_loss : 0.09051405638456345
# epoch : 3, globaliter : 159, batch_idx  : 27, triplet_loss : 0.09100475162267685
# epoch : 3, globaliter : 160, batch_idx  : 28, triplet_loss : 0.09321088343858719
# epoch : 3, globaliter : 161, batch_idx  : 29, triplet_loss : 0.09940775483846664
# epoch : 3, globaliter : 162, batch_idx  : 30, triplet_loss : 0.0930776596069336
# epoch : 3, globaliter : 163, batch_idx  : 31, triplet_loss : 0.09745602309703827
# epoch : 3, globaliter : 164, batch_idx  : 32, triplet_loss : 0.09232868999242783
# epoch : 3, globaliter : 165, batch_idx  : 33, triplet_loss : 0.09431091696023941
# epoch : 3, globaliter : 166, batch_idx  : 34, triplet_loss : 0.0962718054652214
# epoch : 3, globaliter : 167, batch_idx  : 35, triplet_loss : 0.08769205212593079
# epoch : 3, globaliter : 168, batch_idx  : 36, triplet_loss : 0.09570031613111496
# epoch : 3, globaliter : 169, batch_idx  : 37, triplet_loss : 0.09005523473024368
# epoch : 3, globaliter : 170, batch_idx  : 38, triplet_loss : 0.09123948961496353
# epoch : 3, globaliter : 171, batch_idx  : 39, triplet_loss : 0.08937905728816986
# epoch : 3, globaliter : 172, batch_idx  : 40, triplet_loss : 0.09681518375873566
# epoch : 3, globaliter : 173, batch_idx  : 41, triplet_loss : 0.09057062864303589
# epoch : 3, globaliter : 174, batch_idx  : 42, triplet_loss : 0.09583822637796402
# epoch : 3, globaliter : 175, batch_idx  : 43, triplet_loss : 0.0
# epoch : 4, globaliter : 176, batch_idx  : 0, triplet_loss : 0.09183385968208313
# epoch : 4, globaliter : 177, batch_idx  : 1, triplet_loss : 0.09639624506235123
# epoch : 4, globaliter : 178, batch_idx  : 2, triplet_loss : 0.09313222020864487
# epoch : 4, globaliter : 179, batch_idx  : 3, triplet_loss : 0.09387721121311188
# epoch : 4, globaliter : 180, batch_idx  : 4, triplet_loss : 0.09354197978973389
# epoch : 4, globaliter : 181, batch_idx  : 5, triplet_loss : 0.09514410048723221
# epoch : 4, globaliter : 182, batch_idx  : 6, triplet_loss : 0.08881448209285736
# epoch : 4, globaliter : 183, batch_idx  : 7, triplet_loss : 0.08984652906656265
# epoch : 4, globaliter : 184, batch_idx  : 8, triplet_loss : 0.09385046362876892
# epoch : 4, globaliter : 185, batch_idx  : 9, triplet_loss : 0.08422109484672546
# epoch : 4, globaliter : 186, batch_idx  : 10, triplet_loss : 0.09158334136009216
# epoch : 4, globaliter : 187, batch_idx  : 11, triplet_loss : 0.09291578829288483
# epoch : 4, globaliter : 188, batch_idx  : 12, triplet_loss : 0.09131161123514175
# epoch : 4, globaliter : 189, batch_idx  : 13, triplet_loss : 0.0860573798418045
# epoch : 4, globaliter : 190, batch_idx  : 14, triplet_loss : 0.09264659136533737
# epoch : 4, globaliter : 191, batch_idx  : 15, triplet_loss : 0.08956339210271835
# epoch : 4, globaliter : 192, batch_idx  : 16, triplet_loss : 0.09159999340772629
# epoch : 4, globaliter : 193, batch_idx  : 17, triplet_loss : 0.08800210803747177
# epoch : 4, globaliter : 194, batch_idx  : 18, triplet_loss : 0.09671822935342789
# epoch : 4, globaliter : 195, batch_idx  : 19, triplet_loss : 0.08951905369758606
# epoch : 4, globaliter : 196, batch_idx  : 20, triplet_loss : 0.09037578850984573
# epoch : 4, globaliter : 197, batch_idx  : 21, triplet_loss : 0.08942326158285141
# epoch : 4, globaliter : 198, batch_idx  : 22, triplet_loss : 0.08680897206068039
# epoch : 4, globaliter : 199, batch_idx  : 23, triplet_loss : 0.09415605664253235
# epoch : 4, globaliter : 200, batch_idx  : 24, triplet_loss : 0.0848342701792717
# epoch : 4, globaliter : 201, batch_idx  : 25, triplet_loss : 0.08886313438415527
# epoch : 4, globaliter : 202, batch_idx  : 26, triplet_loss : 0.091188944876194
# epoch : 4, globaliter : 203, batch_idx  : 27, triplet_loss : 0.08846929669380188
# epoch : 4, globaliter : 204, batch_idx  : 28, triplet_loss : 0.08456501364707947
# epoch : 4, globaliter : 205, batch_idx  : 29, triplet_loss : 0.0893290638923645
# epoch : 4, globaliter : 206, batch_idx  : 30, triplet_loss : 0.09698019176721573
# epoch : 4, globaliter : 207, batch_idx  : 31, triplet_loss : 0.08675502240657806
# epoch : 4, globaliter : 208, batch_idx  : 32, triplet_loss : 0.09807343035936356
# epoch : 4, globaliter : 209, batch_idx  : 33, triplet_loss : 0.08533375710248947
# epoch : 4, globaliter : 210, batch_idx  : 34, triplet_loss : 0.0898343026638031
# epoch : 4, globaliter : 211, batch_idx  : 35, triplet_loss : 0.0954209640622139
# epoch : 4, globaliter : 212, batch_idx  : 36, triplet_loss : 0.08552033454179764
# epoch : 4, globaliter : 213, batch_idx  : 37, triplet_loss : 0.09106827527284622
# epoch : 4, globaliter : 214, batch_idx  : 38, triplet_loss : 0.09563059359788895
# epoch : 4, globaliter : 215, batch_idx  : 39, triplet_loss : 0.0960155799984932
# epoch : 4, globaliter : 216, batch_idx  : 40, triplet_loss : 0.08823841065168381
# epoch : 4, globaliter : 217, batch_idx  : 41, triplet_loss : 0.09121938049793243
# epoch : 4, globaliter : 218, batch_idx  : 42, triplet_loss : 0.0815967544913292
# epoch : 4, globaliter : 219, batch_idx  : 43, triplet_loss : 0.0
# epoch : 5, globaliter : 220, batch_idx  : 0, triplet_loss : 0.08089271187782288
# epoch : 5, globaliter : 221, batch_idx  : 1, triplet_loss : 0.08730359375476837
# epoch : 5, globaliter : 222, batch_idx  : 2, triplet_loss : 0.09206520020961761
# epoch : 5, globaliter : 223, batch_idx  : 3, triplet_loss : 0.09751884639263153
# epoch : 5, globaliter : 224, batch_idx  : 4, triplet_loss : 0.08566389232873917
# epoch : 5, globaliter : 225, batch_idx  : 5, triplet_loss : 0.09409381449222565
# epoch : 5, globaliter : 226, batch_idx  : 6, triplet_loss : 0.08583617955446243
# epoch : 5, globaliter : 227, batch_idx  : 7, triplet_loss : 0.08394388854503632
# epoch : 5, globaliter : 228, batch_idx  : 8, triplet_loss : 0.0852925181388855
# epoch : 5, globaliter : 229, batch_idx  : 9, triplet_loss : 0.09238521009683609
# epoch : 5, globaliter : 230, batch_idx  : 10, triplet_loss : 0.08707322925329208
# epoch : 5, globaliter : 231, batch_idx  : 11, triplet_loss : 0.08719730377197266
# epoch : 5, globaliter : 232, batch_idx  : 12, triplet_loss : 0.08872486650943756
# epoch : 5, globaliter : 233, batch_idx  : 13, triplet_loss : 0.0816926583647728
# epoch : 5, globaliter : 234, batch_idx  : 14, triplet_loss : 0.09041287004947662
# epoch : 5, globaliter : 235, batch_idx  : 15, triplet_loss : 0.08415878564119339
# epoch : 5, globaliter : 236, batch_idx  : 16, triplet_loss : 0.09765321761369705
# epoch : 5, globaliter : 237, batch_idx  : 17, triplet_loss : 0.09340306371450424
# epoch : 5, globaliter : 238, batch_idx  : 18, triplet_loss : 0.08229799568653107
# epoch : 5, globaliter : 239, batch_idx  : 19, triplet_loss : 0.0797090157866478
# epoch : 5, globaliter : 240, batch_idx  : 20, triplet_loss : 0.0812440738081932
# epoch : 5, globaliter : 241, batch_idx  : 21, triplet_loss : 0.09075507521629333
# epoch : 5, globaliter : 242, batch_idx  : 22, triplet_loss : 0.08803337067365646
# epoch : 5, globaliter : 243, batch_idx  : 23, triplet_loss : 0.07964679598808289
# epoch : 5, globaliter : 244, batch_idx  : 24, triplet_loss : 0.0956619456410408
# epoch : 5, globaliter : 245, batch_idx  : 25, triplet_loss : 0.08450192958116531
# epoch : 5, globaliter : 246, batch_idx  : 26, triplet_loss : 0.07393129914999008
# epoch : 5, globaliter : 247, batch_idx  : 27, triplet_loss : 0.07974682003259659
# epoch : 5, globaliter : 248, batch_idx  : 28, triplet_loss : 0.07983604818582535
# epoch : 5, globaliter : 249, batch_idx  : 29, triplet_loss : 0.08383812755346298
# epoch : 5, globaliter : 250, batch_idx  : 30, triplet_loss : 0.08609539270401001
# epoch : 5, globaliter : 251, batch_idx  : 31, triplet_loss : 0.08574312925338745
# epoch : 5, globaliter : 252, batch_idx  : 32, triplet_loss : 0.08256955444812775
# epoch : 5, globaliter : 253, batch_idx  : 33, triplet_loss : 0.08712694048881531
# epoch : 5, globaliter : 254, batch_idx  : 34, triplet_loss : 0.07924796640872955
# epoch : 5, globaliter : 255, batch_idx  : 35, triplet_loss : 0.0876636952161789
# epoch : 5, globaliter : 256, batch_idx  : 36, triplet_loss : 0.08153137564659119
# epoch : 5, globaliter : 257, batch_idx  : 37, triplet_loss : 0.07968753576278687
# epoch : 5, globaliter : 258, batch_idx  : 38, triplet_loss : 0.09679064899682999
# epoch : 5, globaliter : 259, batch_idx  : 39, triplet_loss : 0.08961502462625504
# epoch : 5, globaliter : 260, batch_idx  : 40, triplet_loss : 0.07683826982975006
# epoch : 5, globaliter : 261, batch_idx  : 41, triplet_loss : 0.07458332926034927
# epoch : 5, globaliter : 262, batch_idx  : 42, triplet_loss : 0.09424284100532532
# epoch : 5, globaliter : 263, batch_idx  : 43, triplet_loss : 0.0
# epoch : 6, globaliter : 264, batch_idx  : 0, triplet_loss : 0.09447868913412094
# epoch : 6, globaliter : 265, batch_idx  : 1, triplet_loss : 0.08764328807592392
# epoch : 6, globaliter : 266, batch_idx  : 2, triplet_loss : 0.08291159570217133
# epoch : 6, globaliter : 267, batch_idx  : 3, triplet_loss : 0.08179782330989838
# epoch : 6, globaliter : 268, batch_idx  : 4, triplet_loss : 0.07110783457756042
# epoch : 6, globaliter : 269, batch_idx  : 5, triplet_loss : 0.08264943957328796
# epoch : 6, globaliter : 270, batch_idx  : 6, triplet_loss : 0.08855514973402023
# epoch : 6, globaliter : 271, batch_idx  : 7, triplet_loss : 0.07658105343580246
# epoch : 6, globaliter : 272, batch_idx  : 8, triplet_loss : 0.09307987987995148
# epoch : 6, globaliter : 273, batch_idx  : 9, triplet_loss : 0.07359852641820908
# epoch : 6, globaliter : 274, batch_idx  : 10, triplet_loss : 0.07347588241100311
# epoch : 6, globaliter : 275, batch_idx  : 11, triplet_loss : 0.09094630181789398
# epoch : 6, globaliter : 276, batch_idx  : 12, triplet_loss : 0.08709953725337982
# epoch : 6, globaliter : 277, batch_idx  : 13, triplet_loss : 0.0865272805094719
# epoch : 6, globaliter : 278, batch_idx  : 14, triplet_loss : 0.07593200355768204
# epoch : 6, globaliter : 279, batch_idx  : 15, triplet_loss : 0.09718004614114761
# epoch : 6, globaliter : 280, batch_idx  : 16, triplet_loss : 0.07707896083593369
# epoch : 6, globaliter : 281, batch_idx  : 17, triplet_loss : 0.0784851461648941
# epoch : 6, globaliter : 282, batch_idx  : 18, triplet_loss : 0.09171000868082047
# epoch : 6, globaliter : 283, batch_idx  : 19, triplet_loss : 0.10136327892541885
# epoch : 6, globaliter : 284, batch_idx  : 20, triplet_loss : 0.08945217728614807
# epoch : 6, globaliter : 285, batch_idx  : 21, triplet_loss : 0.07715430110692978
# epoch : 6, globaliter : 286, batch_idx  : 22, triplet_loss : 0.08164117485284805
# epoch : 6, globaliter : 287, batch_idx  : 23, triplet_loss : 0.08323512971401215
# epoch : 6, globaliter : 288, batch_idx  : 24, triplet_loss : 0.0762321949005127
# epoch : 6, globaliter : 289, batch_idx  : 25, triplet_loss : 0.0780041366815567
# epoch : 6, globaliter : 290, batch_idx  : 26, triplet_loss : 0.06786986440420151
# epoch : 6, globaliter : 291, batch_idx  : 27, triplet_loss : 0.07539723813533783
# epoch : 6, globaliter : 292, batch_idx  : 28, triplet_loss : 0.07988245040178299
# epoch : 6, globaliter : 293, batch_idx  : 29, triplet_loss : 0.07166220247745514
# epoch : 6, globaliter : 294, batch_idx  : 30, triplet_loss : 0.07170955836772919
# epoch : 6, globaliter : 295, batch_idx  : 31, triplet_loss : 0.08072768896818161
# epoch : 6, globaliter : 296, batch_idx  : 32, triplet_loss : 0.07745511084794998
# epoch : 6, globaliter : 297, batch_idx  : 33, triplet_loss : 0.065224289894104
# epoch : 6, globaliter : 298, batch_idx  : 34, triplet_loss : 0.08537925779819489
# epoch : 6, globaliter : 299, batch_idx  : 35, triplet_loss : 0.07019205391407013
# epoch : 6, globaliter : 300, batch_idx  : 36, triplet_loss : 0.06844192743301392
# epoch : 6, globaliter : 301, batch_idx  : 37, triplet_loss : 0.08110196143388748
# epoch : 6, globaliter : 302, batch_idx  : 38, triplet_loss : 0.07620566338300705
# epoch : 6, globaliter : 303, batch_idx  : 39, triplet_loss : 0.07444065064191818
# epoch : 6, globaliter : 304, batch_idx  : 40, triplet_loss : 0.07573451846837997
# epoch : 6, globaliter : 305, batch_idx  : 41, triplet_loss : 0.08375554531812668
# epoch : 6, globaliter : 306, batch_idx  : 42, triplet_loss : 0.07311592251062393
# epoch : 6, globaliter : 307, batch_idx  : 43, triplet_loss : 0.0
# epoch : 7, globaliter : 308, batch_idx  : 0, triplet_loss : 0.08775491267442703
# epoch : 7, globaliter : 309, batch_idx  : 1, triplet_loss : 0.06533632427453995
# epoch : 7, globaliter : 310, batch_idx  : 2, triplet_loss : 0.08628872036933899
# epoch : 7, globaliter : 311, batch_idx  : 3, triplet_loss : 0.08120335638523102
# epoch : 7, globaliter : 312, batch_idx  : 4, triplet_loss : 0.08981965482234955
# epoch : 7, globaliter : 313, batch_idx  : 5, triplet_loss : 0.09152892231941223
# epoch : 7, globaliter : 314, batch_idx  : 6, triplet_loss : 0.06656532734632492
# epoch : 7, globaliter : 315, batch_idx  : 7, triplet_loss : 0.08212585002183914
# epoch : 7, globaliter : 316, batch_idx  : 8, triplet_loss : 0.06808029115200043
# epoch : 7, globaliter : 317, batch_idx  : 9, triplet_loss : 0.07846754044294357
# epoch : 7, globaliter : 318, batch_idx  : 10, triplet_loss : 0.07396190613508224
# epoch : 7, globaliter : 319, batch_idx  : 11, triplet_loss : 0.07310537993907928
# epoch : 7, globaliter : 320, batch_idx  : 12, triplet_loss : 0.07006142288446426
# epoch : 7, globaliter : 321, batch_idx  : 13, triplet_loss : 0.07199307531118393
# epoch : 7, globaliter : 322, batch_idx  : 14, triplet_loss : 0.0644284263253212
# epoch : 7, globaliter : 323, batch_idx  : 15, triplet_loss : 0.0806293785572052
# epoch : 7, globaliter : 324, batch_idx  : 16, triplet_loss : 0.08238491415977478
# epoch : 7, globaliter : 325, batch_idx  : 17, triplet_loss : 0.09268556535243988
# epoch : 7, globaliter : 326, batch_idx  : 18, triplet_loss : 0.09032077342271805
# epoch : 7, globaliter : 327, batch_idx  : 19, triplet_loss : 0.05696943774819374
# epoch : 7, globaliter : 328, batch_idx  : 20, triplet_loss : 0.05978281423449516
# epoch : 7, globaliter : 329, batch_idx  : 21, triplet_loss : 0.08890882879495621
# epoch : 7, globaliter : 330, batch_idx  : 22, triplet_loss : 0.07886078953742981
# epoch : 7, globaliter : 331, batch_idx  : 23, triplet_loss : 0.077983058989048
# epoch : 7, globaliter : 332, batch_idx  : 24, triplet_loss : 0.06931030750274658
# epoch : 7, globaliter : 333, batch_idx  : 25, triplet_loss : 0.06711598485708237
# epoch : 7, globaliter : 334, batch_idx  : 26, triplet_loss : 0.0675286054611206
# epoch : 7, globaliter : 335, batch_idx  : 27, triplet_loss : 0.06856397539377213
# epoch : 7, globaliter : 336, batch_idx  : 28, triplet_loss : 0.08186686784029007
# epoch : 7, globaliter : 337, batch_idx  : 29, triplet_loss : 0.056467048823833466
# epoch : 7, globaliter : 338, batch_idx  : 30, triplet_loss : 0.05861399322748184
# epoch : 7, globaliter : 339, batch_idx  : 31, triplet_loss : 0.0818028450012207
# epoch : 7, globaliter : 340, batch_idx  : 32, triplet_loss : 0.06976857781410217
# epoch : 7, globaliter : 341, batch_idx  : 33, triplet_loss : 0.06448237597942352
# epoch : 7, globaliter : 342, batch_idx  : 34, triplet_loss : 0.06209529936313629
# epoch : 7, globaliter : 343, batch_idx  : 35, triplet_loss : 0.05592788755893707
# epoch : 7, globaliter : 344, batch_idx  : 36, triplet_loss : 0.05053357779979706
# epoch : 7, globaliter : 345, batch_idx  : 37, triplet_loss : 0.04351837560534477
# epoch : 7, globaliter : 346, batch_idx  : 38, triplet_loss : 0.0927758514881134
# epoch : 7, globaliter : 347, batch_idx  : 39, triplet_loss : 0.0678267702460289
# epoch : 7, globaliter : 348, batch_idx  : 40, triplet_loss : 0.06908182054758072
# epoch : 7, globaliter : 349, batch_idx  : 41, triplet_loss : 0.08573642373085022
# epoch : 7, globaliter : 350, batch_idx  : 42, triplet_loss : 0.07485443353652954
# epoch : 7, globaliter : 351, batch_idx  : 43, triplet_loss : 0.0
# epoch : 8, globaliter : 352, batch_idx  : 0, triplet_loss : 0.04465876519680023
# epoch : 8, globaliter : 353, batch_idx  : 1, triplet_loss : 0.08228129148483276
# epoch : 8, globaliter : 354, batch_idx  : 2, triplet_loss : 0.06346830725669861
# epoch : 8, globaliter : 355, batch_idx  : 3, triplet_loss : 0.0718703642487526
# epoch : 8, globaliter : 356, batch_idx  : 4, triplet_loss : 0.07670210301876068
# epoch : 8, globaliter : 357, batch_idx  : 5, triplet_loss : 0.04849519208073616
# epoch : 8, globaliter : 358, batch_idx  : 6, triplet_loss : 0.04201483726501465
# epoch : 8, globaliter : 359, batch_idx  : 7, triplet_loss : 0.053983815014362335
# epoch : 8, globaliter : 360, batch_idx  : 8, triplet_loss : 0.061016470193862915
# epoch : 8, globaliter : 361, batch_idx  : 9, triplet_loss : 0.07037608325481415
# epoch : 8, globaliter : 362, batch_idx  : 10, triplet_loss : 0.061632826924324036
# epoch : 8, globaliter : 363, batch_idx  : 11, triplet_loss : 0.04766060411930084
# epoch : 8, globaliter : 364, batch_idx  : 12, triplet_loss : 0.07565286755561829
# epoch : 8, globaliter : 365, batch_idx  : 13, triplet_loss : 0.06272894144058228
# epoch : 8, globaliter : 366, batch_idx  : 14, triplet_loss : 0.061234816908836365
# epoch : 8, globaliter : 367, batch_idx  : 15, triplet_loss : 0.06270056217908859
# epoch : 8, globaliter : 368, batch_idx  : 16, triplet_loss : 0.06881143152713776
# epoch : 8, globaliter : 369, batch_idx  : 17, triplet_loss : 0.060701388865709305
# epoch : 8, globaliter : 370, batch_idx  : 18, triplet_loss : 0.044783782213926315
# epoch : 8, globaliter : 371, batch_idx  : 19, triplet_loss : 0.07306897640228271
# epoch : 8, globaliter : 372, batch_idx  : 20, triplet_loss : 0.07351730763912201
# epoch : 8, globaliter : 373, batch_idx  : 21, triplet_loss : 0.0611366368830204
# epoch : 8, globaliter : 374, batch_idx  : 22, triplet_loss : 0.04860857501626015
# epoch : 8, globaliter : 375, batch_idx  : 23, triplet_loss : 0.05825069174170494
# epoch : 8, globaliter : 376, batch_idx  : 24, triplet_loss : 0.07340725511312485
# epoch : 8, globaliter : 377, batch_idx  : 25, triplet_loss : 0.0833670124411583
# epoch : 8, globaliter : 378, batch_idx  : 26, triplet_loss : 0.0937715619802475
# epoch : 8, globaliter : 379, batch_idx  : 27, triplet_loss : 0.04427313804626465
# epoch : 8, globaliter : 380, batch_idx  : 28, triplet_loss : 0.058573491871356964
# epoch : 8, globaliter : 381, batch_idx  : 29, triplet_loss : 0.05723296105861664
# epoch : 8, globaliter : 382, batch_idx  : 30, triplet_loss : 0.08687804639339447
# epoch : 8, globaliter : 383, batch_idx  : 31, triplet_loss : 0.05097160115838051
# epoch : 8, globaliter : 384, batch_idx  : 32, triplet_loss : 0.049084749072790146
# epoch : 8, globaliter : 385, batch_idx  : 33, triplet_loss : 0.05566731467843056
# epoch : 8, globaliter : 386, batch_idx  : 34, triplet_loss : 0.05610349401831627
# epoch : 8, globaliter : 387, batch_idx  : 35, triplet_loss : 0.05277254059910774
# epoch : 8, globaliter : 388, batch_idx  : 36, triplet_loss : 0.05924006924033165
# epoch : 8, globaliter : 389, batch_idx  : 37, triplet_loss : 0.04239986836910248
# epoch : 8, globaliter : 390, batch_idx  : 38, triplet_loss : 0.039990589022636414
# epoch : 8, globaliter : 391, batch_idx  : 39, triplet_loss : 0.06492875516414642
# epoch : 8, globaliter : 392, batch_idx  : 40, triplet_loss : 0.06630712002515793
# epoch : 8, globaliter : 393, batch_idx  : 41, triplet_loss : 0.07719053328037262
# epoch : 8, globaliter : 394, batch_idx  : 42, triplet_loss : 0.05209925398230553
# epoch : 8, globaliter : 395, batch_idx  : 43, triplet_loss : 0.0
# epoch : 9, globaliter : 396, batch_idx  : 0, triplet_loss : 0.04743025824427605
# epoch : 9, globaliter : 397, batch_idx  : 1, triplet_loss : 0.039317693561315536
# epoch : 9, globaliter : 398, batch_idx  : 2, triplet_loss : 0.0791177749633789
# epoch : 9, globaliter : 399, batch_idx  : 3, triplet_loss : 0.06721051782369614
# epoch : 9, globaliter : 400, batch_idx  : 4, triplet_loss : 0.048009224236011505
# epoch : 9, globaliter : 401, batch_idx  : 5, triplet_loss : 0.07758602499961853
# epoch : 9, globaliter : 402, batch_idx  : 6, triplet_loss : 0.05393074080348015
# epoch : 9, globaliter : 403, batch_idx  : 7, triplet_loss : 0.04069582745432854
# epoch : 9, globaliter : 404, batch_idx  : 8, triplet_loss : 0.03622276335954666
# epoch : 9, globaliter : 405, batch_idx  : 9, triplet_loss : 0.09893868118524551
# epoch : 9, globaliter : 406, batch_idx  : 10, triplet_loss : 0.03369821608066559
# epoch : 9, globaliter : 407, batch_idx  : 11, triplet_loss : 0.040896255522966385
# epoch : 9, globaliter : 408, batch_idx  : 12, triplet_loss : 0.0
# epoch : 9, globaliter : 409, batch_idx  : 13, triplet_loss : 0.043052203953266144
# epoch : 9, globaliter : 410, batch_idx  : 14, triplet_loss : 0.048660583794116974
# epoch : 9, globaliter : 411, batch_idx  : 15, triplet_loss : 0.05737593397498131
# epoch : 9, globaliter : 412, batch_idx  : 16, triplet_loss : 0.0790625587105751
# epoch : 9, globaliter : 413, batch_idx  : 17, triplet_loss : 0.06274159997701645
# epoch : 9, globaliter : 414, batch_idx  : 18, triplet_loss : 0.03838770091533661
# epoch : 9, globaliter : 415, batch_idx  : 19, triplet_loss : 0.07774826139211655
# epoch : 9, globaliter : 416, batch_idx  : 20, triplet_loss : 0.06896598637104034
# epoch : 9, globaliter : 417, batch_idx  : 21, triplet_loss : 0.04025576636195183
# epoch : 9, globaliter : 418, batch_idx  : 22, triplet_loss : 0.08471271395683289
# epoch : 9, globaliter : 419, batch_idx  : 23, triplet_loss : 0.09865999221801758
# epoch : 9, globaliter : 420, batch_idx  : 24, triplet_loss : 0.061316926032304764
# epoch : 9, globaliter : 421, batch_idx  : 25, triplet_loss : 0.059812672436237335
# epoch : 9, globaliter : 422, batch_idx  : 26, triplet_loss : 0.10116562992334366
# epoch : 9, globaliter : 423, batch_idx  : 27, triplet_loss : 0.058843884617090225
# epoch : 9, globaliter : 424, batch_idx  : 28, triplet_loss : 0.05677318572998047
# epoch : 9, globaliter : 425, batch_idx  : 29, triplet_loss : 0.07908379286527634
# epoch : 9, globaliter : 426, batch_idx  : 30, triplet_loss : 0.08480223268270493
# epoch : 9, globaliter : 427, batch_idx  : 31, triplet_loss : 0.04548419639468193
# epoch : 9, globaliter : 428, batch_idx  : 32, triplet_loss : 0.05760575458407402
# epoch : 9, globaliter : 429, batch_idx  : 33, triplet_loss : 0.0712369978427887
# epoch : 9, globaliter : 430, batch_idx  : 34, triplet_loss : 0.061834920197725296
# epoch : 9, globaliter : 431, batch_idx  : 35, triplet_loss : 0.08322181552648544
# epoch : 9, globaliter : 432, batch_idx  : 36, triplet_loss : 0.03643990680575371
# epoch : 9, globaliter : 433, batch_idx  : 37, triplet_loss : 0.04398657754063606
# epoch : 9, globaliter : 434, batch_idx  : 38, triplet_loss : 0.07985040545463562
# epoch : 9, globaliter : 435, batch_idx  : 39, triplet_loss : 0.060286737978458405
# epoch : 9, globaliter : 436, batch_idx  : 40, triplet_loss : 0.022963548079133034
# epoch : 9, globaliter : 437, batch_idx  : 41, triplet_loss : 0.07589031755924225
# epoch : 9, globaliter : 438, batch_idx  : 42, triplet_loss : 0.049778204411268234
# epoch : 9, globaliter : 439, batch_idx  : 43, triplet_loss : 0.0
# epoch : 10, globaliter : 440, batch_idx  : 0, triplet_loss : 0.05360805243253708
# epoch : 10, globaliter : 441, batch_idx  : 1, triplet_loss : 0.05159284174442291
# epoch : 10, globaliter : 442, batch_idx  : 2, triplet_loss : 0.03285612538456917
# epoch : 10, globaliter : 443, batch_idx  : 3, triplet_loss : 0.04569191485643387
# epoch : 10, globaliter : 444, batch_idx  : 4, triplet_loss : 0.05896328017115593
# epoch : 10, globaliter : 445, batch_idx  : 5, triplet_loss : 0.026787126436829567
# epoch : 10, globaliter : 446, batch_idx  : 6, triplet_loss : 0.058659762144088745
# epoch : 10, globaliter : 447, batch_idx  : 7, triplet_loss : 0.06300406157970428
# epoch : 10, globaliter : 448, batch_idx  : 8, triplet_loss : 0.031328026205301285
# epoch : 10, globaliter : 449, batch_idx  : 9, triplet_loss : 0.08450574427843094
# epoch : 10, globaliter : 450, batch_idx  : 10, triplet_loss : 0.05878094956278801
# epoch : 10, globaliter : 451, batch_idx  : 11, triplet_loss : 0.05919871851801872
# epoch : 10, globaliter : 452, batch_idx  : 12, triplet_loss : 0.04160997271537781
# epoch : 10, globaliter : 453, batch_idx  : 13, triplet_loss : 0.045220911502838135
# epoch : 10, globaliter : 454, batch_idx  : 14, triplet_loss : 0.028964972123503685
# epoch : 10, globaliter : 455, batch_idx  : 15, triplet_loss : 0.0536673404276371
# epoch : 10, globaliter : 456, batch_idx  : 16, triplet_loss : 0.03931543603539467
# epoch : 10, globaliter : 457, batch_idx  : 17, triplet_loss : 0.02813299372792244
# epoch : 10, globaliter : 458, batch_idx  : 18, triplet_loss : 0.06429152190685272
# epoch : 10, globaliter : 459, batch_idx  : 19, triplet_loss : 0.06748513132333755
# epoch : 10, globaliter : 460, batch_idx  : 20, triplet_loss : 0.05441093072295189
# epoch : 10, globaliter : 461, batch_idx  : 21, triplet_loss : 0.03547121211886406
# epoch : 10, globaliter : 462, batch_idx  : 22, triplet_loss : 0.06419013440608978
# epoch : 10, globaliter : 463, batch_idx  : 23, triplet_loss : 0.04280035197734833
# epoch : 10, globaliter : 464, batch_idx  : 24, triplet_loss : 0.043544624000787735
# epoch : 10, globaliter : 465, batch_idx  : 25, triplet_loss : 0.08431600034236908
# epoch : 10, globaliter : 466, batch_idx  : 26, triplet_loss : 0.04371432214975357
# epoch : 10, globaliter : 467, batch_idx  : 27, triplet_loss : 0.03173685818910599
# epoch : 10, globaliter : 468, batch_idx  : 28, triplet_loss : 0.08980955183506012
# epoch : 10, globaliter : 469, batch_idx  : 29, triplet_loss : 0.06832373887300491
# epoch : 10, globaliter : 470, batch_idx  : 30, triplet_loss : 0.030950872227549553
# epoch : 10, globaliter : 471, batch_idx  : 31, triplet_loss : 0.04852428659796715
# epoch : 10, globaliter : 472, batch_idx  : 32, triplet_loss : 0.04663170874118805
# epoch : 10, globaliter : 473, batch_idx  : 33, triplet_loss : 0.04545570909976959
# epoch : 10, globaliter : 474, batch_idx  : 34, triplet_loss : 0.04210279509425163
# epoch : 10, globaliter : 475, batch_idx  : 35, triplet_loss : 0.02222008816897869
# epoch : 10, globaliter : 476, batch_idx  : 36, triplet_loss : 0.01908084936439991
# epoch : 10, globaliter : 477, batch_idx  : 37, triplet_loss : 0.03054112009704113
# epoch : 10, globaliter : 478, batch_idx  : 38, triplet_loss : 0.0688289999961853
# epoch : 10, globaliter : 479, batch_idx  : 39, triplet_loss : 0.07623662054538727
# epoch : 10, globaliter : 480, batch_idx  : 40, triplet_loss : 0.05965277925133705
# epoch : 10, globaliter : 481, batch_idx  : 41, triplet_loss : 0.07693386822938919
# epoch : 10, globaliter : 482, batch_idx  : 42, triplet_loss : 0.03818937763571739
# epoch : 10, globaliter : 483, batch_idx  : 43, triplet_loss : 0.0
# epoch : 11, globaliter : 484, batch_idx  : 0, triplet_loss : 0.03492998704314232
# epoch : 11, globaliter : 485, batch_idx  : 1, triplet_loss : 0.05201907455921173
# epoch : 11, globaliter : 486, batch_idx  : 2, triplet_loss : 0.049446891993284225
# epoch : 11, globaliter : 487, batch_idx  : 3, triplet_loss : 0.05443616211414337
# epoch : 11, globaliter : 488, batch_idx  : 4, triplet_loss : 0.07217121124267578
# epoch : 11, globaliter : 489, batch_idx  : 5, triplet_loss : 0.05687222257256508
# epoch : 11, globaliter : 490, batch_idx  : 6, triplet_loss : 0.031051231548190117
# epoch : 11, globaliter : 491, batch_idx  : 7, triplet_loss : 0.03402622044086456
# epoch : 11, globaliter : 492, batch_idx  : 8, triplet_loss : 0.08930179476737976
# epoch : 11, globaliter : 493, batch_idx  : 9, triplet_loss : 0.03271351009607315
# epoch : 11, globaliter : 494, batch_idx  : 10, triplet_loss : 0.06224522367119789
# epoch : 11, globaliter : 495, batch_idx  : 11, triplet_loss : 0.026274995878338814
# epoch : 11, globaliter : 496, batch_idx  : 12, triplet_loss : 0.04770442470908165
# epoch : 11, globaliter : 497, batch_idx  : 13, triplet_loss : 0.04961690306663513
# epoch : 11, globaliter : 498, batch_idx  : 14, triplet_loss : 0.03694474697113037
# epoch : 11, globaliter : 499, batch_idx  : 15, triplet_loss : 0.021744156256318092
# epoch : 11, globaliter : 500, batch_idx  : 16, triplet_loss : 0.09021670371294022
# epoch : 11, globaliter : 501, batch_idx  : 17, triplet_loss : 0.02680322900414467
# epoch : 11, globaliter : 502, batch_idx  : 18, triplet_loss : 0.0328652448952198
# epoch : 11, globaliter : 503, batch_idx  : 19, triplet_loss : 0.061213359236717224
# epoch : 11, globaliter : 504, batch_idx  : 20, triplet_loss : 0.02394389547407627
# epoch : 11, globaliter : 505, batch_idx  : 21, triplet_loss : 0.03285793587565422
# epoch : 11, globaliter : 506, batch_idx  : 22, triplet_loss : 0.05303075537085533
# epoch : 11, globaliter : 507, batch_idx  : 23, triplet_loss : 0.04793862998485565
# epoch : 11, globaliter : 508, batch_idx  : 24, triplet_loss : 0.03557591885328293
# epoch : 11, globaliter : 509, batch_idx  : 25, triplet_loss : 0.06286899745464325
# epoch : 11, globaliter : 510, batch_idx  : 26, triplet_loss : 0.08949967473745346
# epoch : 11, globaliter : 511, batch_idx  : 27, triplet_loss : 0.02312762476503849
# epoch : 11, globaliter : 512, batch_idx  : 28, triplet_loss : 0.03584251552820206
# epoch : 11, globaliter : 513, batch_idx  : 29, triplet_loss : 0.08135330677032471
# epoch : 11, globaliter : 514, batch_idx  : 30, triplet_loss : 0.01922553777694702
# epoch : 11, globaliter : 515, batch_idx  : 31, triplet_loss : 0.06451364606618881
# epoch : 11, globaliter : 516, batch_idx  : 32, triplet_loss : 0.06645326316356659
# epoch : 11, globaliter : 517, batch_idx  : 33, triplet_loss : 0.03186512365937233
# epoch : 11, globaliter : 518, batch_idx  : 34, triplet_loss : 0.03561849147081375
# epoch : 11, globaliter : 519, batch_idx  : 35, triplet_loss : 0.04924582317471504
# epoch : 11, globaliter : 520, batch_idx  : 36, triplet_loss : 0.05505122244358063
# epoch : 11, globaliter : 521, batch_idx  : 37, triplet_loss : 0.08822435885667801
# epoch : 11, globaliter : 522, batch_idx  : 38, triplet_loss : 0.07422377914190292
# epoch : 11, globaliter : 523, batch_idx  : 39, triplet_loss : 0.017411619424819946
# epoch : 11, globaliter : 524, batch_idx  : 40, triplet_loss : 0.027388954535126686
# epoch : 11, globaliter : 525, batch_idx  : 41, triplet_loss : 0.052826374769210815
# epoch : 11, globaliter : 526, batch_idx  : 42, triplet_loss : 0.0759669616818428
# epoch : 11, globaliter : 527, batch_idx  : 43, triplet_loss : 0.0
# epoch : 12, globaliter : 528, batch_idx  : 0, triplet_loss : 0.03472135215997696
# epoch : 12, globaliter : 529, batch_idx  : 1, triplet_loss : 0.020579112693667412
# epoch : 12, globaliter : 530, batch_idx  : 2, triplet_loss : 0.021623242646455765
# epoch : 12, globaliter : 531, batch_idx  : 3, triplet_loss : 0.05709639564156532
# epoch : 12, globaliter : 532, batch_idx  : 4, triplet_loss : 0.06732002645730972
# epoch : 12, globaliter : 533, batch_idx  : 5, triplet_loss : 0.07315722852945328
# epoch : 12, globaliter : 534, batch_idx  : 6, triplet_loss : 0.01765080913901329
# epoch : 12, globaliter : 535, batch_idx  : 7, triplet_loss : 0.028826404362916946
# epoch : 12, globaliter : 536, batch_idx  : 8, triplet_loss : 0.04318799823522568
# epoch : 12, globaliter : 537, batch_idx  : 9, triplet_loss : 0.06122789904475212
# epoch : 12, globaliter : 538, batch_idx  : 10, triplet_loss : 0.05767278000712395
# epoch : 12, globaliter : 539, batch_idx  : 11, triplet_loss : 0.020723065361380577
# epoch : 12, globaliter : 540, batch_idx  : 12, triplet_loss : 0.04935011640191078
# epoch : 12, globaliter : 541, batch_idx  : 13, triplet_loss : 0.024967819452285767
# epoch : 12, globaliter : 542, batch_idx  : 14, triplet_loss : 0.04053477942943573
# epoch : 12, globaliter : 543, batch_idx  : 15, triplet_loss : 0.06690265983343124
# epoch : 12, globaliter : 544, batch_idx  : 16, triplet_loss : 0.07189501076936722
# epoch : 12, globaliter : 545, batch_idx  : 17, triplet_loss : 0.04421474412083626
# epoch : 12, globaliter : 546, batch_idx  : 18, triplet_loss : 0.06623698770999908
# epoch : 12, globaliter : 547, batch_idx  : 19, triplet_loss : 0.04003553092479706
# epoch : 12, globaliter : 548, batch_idx  : 20, triplet_loss : 0.07571231573820114
# epoch : 12, globaliter : 549, batch_idx  : 21, triplet_loss : 0.05236705020070076
# epoch : 12, globaliter : 550, batch_idx  : 22, triplet_loss : 0.0386589914560318
# epoch : 12, globaliter : 551, batch_idx  : 23, triplet_loss : 0.024235112592577934
# epoch : 12, globaliter : 552, batch_idx  : 24, triplet_loss : 0.022761521860957146
# epoch : 12, globaliter : 553, batch_idx  : 25, triplet_loss : 0.02495427615940571
# epoch : 12, globaliter : 554, batch_idx  : 26, triplet_loss : 0.01561690028756857
# epoch : 12, globaliter : 555, batch_idx  : 27, triplet_loss : 0.05491664633154869
# epoch : 12, globaliter : 556, batch_idx  : 28, triplet_loss : 0.011241990141570568
# epoch : 12, globaliter : 557, batch_idx  : 29, triplet_loss : 0.09198912978172302
# epoch : 12, globaliter : 558, batch_idx  : 30, triplet_loss : 0.02631429210305214
# epoch : 12, globaliter : 559, batch_idx  : 31, triplet_loss : 0.05343946814537048
# epoch : 12, globaliter : 560, batch_idx  : 32, triplet_loss : 0.03500312939286232
# epoch : 12, globaliter : 561, batch_idx  : 33, triplet_loss : 0.049666665494441986
# epoch : 12, globaliter : 562, batch_idx  : 34, triplet_loss : 0.07900048047304153
# epoch : 12, globaliter : 563, batch_idx  : 35, triplet_loss : 0.025155028328299522
# epoch : 12, globaliter : 564, batch_idx  : 36, triplet_loss : 0.022288134321570396
# epoch : 12, globaliter : 565, batch_idx  : 37, triplet_loss : 0.018809638917446136
# epoch : 12, globaliter : 566, batch_idx  : 38, triplet_loss : 0.059418097138404846
# epoch : 12, globaliter : 567, batch_idx  : 39, triplet_loss : 0.023378092795610428
# epoch : 12, globaliter : 568, batch_idx  : 40, triplet_loss : 0.02519168145954609
# epoch : 12, globaliter : 569, batch_idx  : 41, triplet_loss : 0.04882354661822319
# epoch : 12, globaliter : 570, batch_idx  : 42, triplet_loss : 0.017565982416272163
# epoch : 12, globaliter : 571, batch_idx  : 43, triplet_loss : 0.0
# epoch : 13, globaliter : 572, batch_idx  : 0, triplet_loss : 0.04273268207907677
# epoch : 13, globaliter : 573, batch_idx  : 1, triplet_loss : 0.015308624133467674
# epoch : 13, globaliter : 574, batch_idx  : 2, triplet_loss : 0.046901486814022064
# epoch : 13, globaliter : 575, batch_idx  : 3, triplet_loss : 0.02979036420583725
# epoch : 13, globaliter : 576, batch_idx  : 4, triplet_loss : 0.013481208123266697
# epoch : 13, globaliter : 577, batch_idx  : 5, triplet_loss : 0.015698280185461044
# epoch : 13, globaliter : 578, batch_idx  : 6, triplet_loss : 0.0551140233874321
# epoch : 13, globaliter : 579, batch_idx  : 7, triplet_loss : 0.02531072311103344
# epoch : 13, globaliter : 580, batch_idx  : 8, triplet_loss : 0.04790451005101204
# epoch : 13, globaliter : 581, batch_idx  : 9, triplet_loss : 0.05260836333036423
# epoch : 13, globaliter : 582, batch_idx  : 10, triplet_loss : 0.015367791056632996
# epoch : 13, globaliter : 583, batch_idx  : 11, triplet_loss : 0.036967795342206955
# epoch : 13, globaliter : 584, batch_idx  : 12, triplet_loss : 0.027754180133342743
# epoch : 13, globaliter : 585, batch_idx  : 13, triplet_loss : 0.015465754084289074
# epoch : 13, globaliter : 586, batch_idx  : 14, triplet_loss : 0.0477452352643013
# epoch : 13, globaliter : 587, batch_idx  : 15, triplet_loss : 0.01864730566740036
# epoch : 13, globaliter : 588, batch_idx  : 16, triplet_loss : 0.045332763344049454
# epoch : 13, globaliter : 589, batch_idx  : 17, triplet_loss : 0.017713436856865883
# epoch : 13, globaliter : 590, batch_idx  : 18, triplet_loss : 0.06882044672966003
# epoch : 13, globaliter : 591, batch_idx  : 19, triplet_loss : 0.07112079113721848
# epoch : 13, globaliter : 592, batch_idx  : 20, triplet_loss : 0.07181819528341293
# epoch : 13, globaliter : 593, batch_idx  : 21, triplet_loss : 0.061918046325445175
# epoch : 13, globaliter : 594, batch_idx  : 22, triplet_loss : 0.015956835821270943
# epoch : 13, globaliter : 595, batch_idx  : 23, triplet_loss : 0.045676667243242264
# ...
# epoch : 45, globaliter : 2000, batch_idx  : 20, triplet_loss : 0.002517998218536377
# epoch : 45, globaliter : 2001, batch_idx  : 21, triplet_loss : 0.05698549747467041
# epoch : 45, globaliter : 2002, batch_idx  : 22, triplet_loss : 0.004256187006831169
# epoch : 45, globaliter : 2003, batch_idx  : 23, triplet_loss : 0.004681562539190054
# epoch : 45, globaliter : 2004, batch_idx  : 24, triplet_loss : 0.005416419357061386
# epoch : 45, globaliter : 2005, batch_idx  : 25, triplet_loss : 0.017966903746128082
# epoch : 45, globaliter : 2006, batch_idx  : 26, triplet_loss : 0.00034685805439949036
# epoch : 45, globaliter : 2007, batch_idx  : 27, triplet_loss : 0.04533577710390091
# epoch : 45, globaliter : 2008, batch_idx  : 28, triplet_loss : 0.01568942330777645
# epoch : 45, globaliter : 2009, batch_idx  : 29, triplet_loss : 0.0032238680869340897
# epoch : 45, globaliter : 2010, batch_idx  : 30, triplet_loss : 0.0023309860844165087
# epoch : 45, globaliter : 2011, batch_idx  : 31, triplet_loss : 0.008017998188734055
# epoch : 45, globaliter : 2012, batch_idx  : 32, triplet_loss : 0.0
# epoch : 45, globaliter : 2013, batch_idx  : 33, triplet_loss : 0.0017980239354074001
# epoch : 45, globaliter : 2014, batch_idx  : 34, triplet_loss : 0.0
# epoch : 45, globaliter : 2015, batch_idx  : 35, triplet_loss : 0.0
# epoch : 45, globaliter : 2016, batch_idx  : 36, triplet_loss : 0.05418416112661362
# epoch : 45, globaliter : 2017, batch_idx  : 37, triplet_loss : 0.02632714994251728
# epoch : 45, globaliter : 2018, batch_idx  : 38, triplet_loss : 0.022137219086289406
# epoch : 45, globaliter : 2019, batch_idx  : 39, triplet_loss : 0.014264056459069252
# epoch : 45, globaliter : 2020, batch_idx  : 40, triplet_loss : 0.005212882068008184
# epoch : 45, globaliter : 2021, batch_idx  : 41, triplet_loss : 0.004100584425032139
# epoch : 45, globaliter : 2022, batch_idx  : 42, triplet_loss : 0.012824694626033306
# epoch : 45, globaliter : 2023, batch_idx  : 43, triplet_loss : 0.0
# epoch : 46, globaliter : 2024, batch_idx  : 0, triplet_loss : 0.0014376714825630188
# epoch : 46, globaliter : 2025, batch_idx  : 1, triplet_loss : 0.0012581485789269209
# epoch : 46, globaliter : 2026, batch_idx  : 2, triplet_loss : 0.0
# epoch : 46, globaliter : 2027, batch_idx  : 3, triplet_loss : 0.002597859362140298
# epoch : 46, globaliter : 2028, batch_idx  : 4, triplet_loss : 0.0
# epoch : 46, globaliter : 2029, batch_idx  : 5, triplet_loss : 0.0016444479115307331
# epoch : 46, globaliter : 2030, batch_idx  : 6, triplet_loss : 0.025257250294089317
# epoch : 46, globaliter : 2031, batch_idx  : 7, triplet_loss : 0.01921844482421875
# epoch : 46, globaliter : 2032, batch_idx  : 8, triplet_loss : 0.013997373171150684
# epoch : 46, globaliter : 2033, batch_idx  : 9, triplet_loss : 0.001064743846654892
# epoch : 46, globaliter : 2034, batch_idx  : 10, triplet_loss : 0.0012489110231399536
# epoch : 46, globaliter : 2035, batch_idx  : 11, triplet_loss : 0.0017522231210023165
# epoch : 46, globaliter : 2036, batch_idx  : 12, triplet_loss : 0.00347672076895833
# epoch : 46, globaliter : 2037, batch_idx  : 13, triplet_loss : 0.003506407141685486
# epoch : 46, globaliter : 2038, batch_idx  : 14, triplet_loss : 0.014975646510720253
# epoch : 46, globaliter : 2039, batch_idx  : 15, triplet_loss : 0.00021288543939590454
# epoch : 46, globaliter : 2040, batch_idx  : 16, triplet_loss : 0.022170227020978928
# epoch : 46, globaliter : 2041, batch_idx  : 17, triplet_loss : 0.0010897790780290961
# epoch : 46, globaliter : 2042, batch_idx  : 18, triplet_loss : 0.0
# epoch : 46, globaliter : 2043, batch_idx  : 19, triplet_loss : 0.0
# epoch : 46, globaliter : 2044, batch_idx  : 20, triplet_loss : 0.007423867005854845
# epoch : 46, globaliter : 2045, batch_idx  : 21, triplet_loss : 0.005123053677380085
# epoch : 46, globaliter : 2046, batch_idx  : 22, triplet_loss : 0.006306184455752373
# epoch : 46, globaliter : 2047, batch_idx  : 23, triplet_loss : 0.003132009878754616
# epoch : 46, globaliter : 2048, batch_idx  : 24, triplet_loss : 0.004865556955337524
# epoch : 46, globaliter : 2049, batch_idx  : 25, triplet_loss : 0.00036572664976119995
# epoch : 46, globaliter : 2050, batch_idx  : 26, triplet_loss : 0.022773070260882378
# epoch : 46, globaliter : 2051, batch_idx  : 27, triplet_loss : 0.0058221109211444855
# epoch : 46, globaliter : 2052, batch_idx  : 28, triplet_loss : 0.04198188707232475
# epoch : 46, globaliter : 2053, batch_idx  : 29, triplet_loss : 0.0
# epoch : 46, globaliter : 2054, batch_idx  : 30, triplet_loss : 0.05668361857533455
# epoch : 46, globaliter : 2055, batch_idx  : 31, triplet_loss : 0.012392915785312653
# epoch : 46, globaliter : 2056, batch_idx  : 32, triplet_loss : 0.016561197116971016
# epoch : 46, globaliter : 2057, batch_idx  : 33, triplet_loss : 0.031201571226119995
# epoch : 46, globaliter : 2058, batch_idx  : 34, triplet_loss : 0.0
# epoch : 46, globaliter : 2059, batch_idx  : 35, triplet_loss : 0.016160152852535248
# epoch : 46, globaliter : 2060, batch_idx  : 36, triplet_loss : 0.001054950407706201
# epoch : 46, globaliter : 2061, batch_idx  : 37, triplet_loss : 0.00023231406521517783
# epoch : 46, globaliter : 2062, batch_idx  : 38, triplet_loss : 0.01655476726591587
# epoch : 46, globaliter : 2063, batch_idx  : 39, triplet_loss : 0.0009025364997796714
# epoch : 46, globaliter : 2064, batch_idx  : 40, triplet_loss : 0.0
# epoch : 46, globaliter : 2065, batch_idx  : 41, triplet_loss : 0.017854683101177216
# epoch : 46, globaliter : 2066, batch_idx  : 42, triplet_loss : 0.0
# epoch : 46, globaliter : 2067, batch_idx  : 43, triplet_loss : 0.0
# epoch : 47, globaliter : 2068, batch_idx  : 0, triplet_loss : 0.005398913286626339
# epoch : 47, globaliter : 2069, batch_idx  : 1, triplet_loss : 0.0
# epoch : 47, globaliter : 2070, batch_idx  : 2, triplet_loss : 0.004287347197532654
# epoch : 47, globaliter : 2071, batch_idx  : 3, triplet_loss : 0.03216387331485748
# epoch : 47, globaliter : 2072, batch_idx  : 4, triplet_loss : 0.000328700989484787
# epoch : 47, globaliter : 2073, batch_idx  : 5, triplet_loss : 0.015392296016216278
# epoch : 47, globaliter : 2074, batch_idx  : 6, triplet_loss : 0.003117002546787262
# epoch : 47, globaliter : 2075, batch_idx  : 7, triplet_loss : 0.0
# epoch : 47, globaliter : 2076, batch_idx  : 8, triplet_loss : 0.0
# epoch : 47, globaliter : 2077, batch_idx  : 9, triplet_loss : 0.0011791214346885681
# epoch : 47, globaliter : 2078, batch_idx  : 10, triplet_loss : 0.0002756193280220032
# epoch : 47, globaliter : 2079, batch_idx  : 11, triplet_loss : 0.026247235015034676
# epoch : 47, globaliter : 2080, batch_idx  : 12, triplet_loss : 0.0
# epoch : 47, globaliter : 2081, batch_idx  : 13, triplet_loss : 0.0
# epoch : 47, globaliter : 2082, batch_idx  : 14, triplet_loss : 0.0
# epoch : 47, globaliter : 2083, batch_idx  : 15, triplet_loss : 0.006279501598328352
# epoch : 47, globaliter : 2084, batch_idx  : 16, triplet_loss : 0.0006240978837013245
# epoch : 47, globaliter : 2085, batch_idx  : 17, triplet_loss : 0.001983723836019635
# epoch : 47, globaliter : 2086, batch_idx  : 18, triplet_loss : 0.0060760085470974445
# epoch : 47, globaliter : 2087, batch_idx  : 19, triplet_loss : 0.017980774864554405
# epoch : 47, globaliter : 2088, batch_idx  : 20, triplet_loss : 0.017346950247883797
# epoch : 47, globaliter : 2089, batch_idx  : 21, triplet_loss : 0.0008426234126091003
# epoch : 47, globaliter : 2090, batch_idx  : 22, triplet_loss : 0.0
# epoch : 47, globaliter : 2091, batch_idx  : 23, triplet_loss : 0.013958871364593506
# epoch : 47, globaliter : 2092, batch_idx  : 24, triplet_loss : 0.02439717948436737
# epoch : 47, globaliter : 2093, batch_idx  : 25, triplet_loss : 0.03298548609018326
# epoch : 47, globaliter : 2094, batch_idx  : 26, triplet_loss : 0.025478731840848923
# epoch : 47, globaliter : 2095, batch_idx  : 27, triplet_loss : 0.013132980093359947
# epoch : 47, globaliter : 2096, batch_idx  : 28, triplet_loss : 0.018632126972079277
# epoch : 47, globaliter : 2097, batch_idx  : 29, triplet_loss : 0.0
# epoch : 47, globaliter : 2098, batch_idx  : 30, triplet_loss : 0.0
# epoch : 47, globaliter : 2099, batch_idx  : 31, triplet_loss : 0.003006528364494443
# epoch : 47, globaliter : 2100, batch_idx  : 32, triplet_loss : 0.005076332483440638
# epoch : 47, globaliter : 2101, batch_idx  : 33, triplet_loss : 0.0
# epoch : 47, globaliter : 2102, batch_idx  : 34, triplet_loss : 0.002087787725031376
# epoch : 47, globaliter : 2103, batch_idx  : 35, triplet_loss : 0.041161973029375076
# epoch : 47, globaliter : 2104, batch_idx  : 36, triplet_loss : 0.006099512800574303
# epoch : 47, globaliter : 2105, batch_idx  : 37, triplet_loss : 0.0020860806107521057
# epoch : 47, globaliter : 2106, batch_idx  : 38, triplet_loss : 0.0007163733243942261
# epoch : 47, globaliter : 2107, batch_idx  : 39, triplet_loss : 0.0011381395161151886
# epoch : 47, globaliter : 2108, batch_idx  : 40, triplet_loss : 0.022396713495254517
# epoch : 47, globaliter : 2109, batch_idx  : 41, triplet_loss : 0.0027451077476143837
# epoch : 47, globaliter : 2110, batch_idx  : 42, triplet_loss : 0.023982569575309753
# epoch : 47, globaliter : 2111, batch_idx  : 43, triplet_loss : 0.0
# epoch : 48, globaliter : 2112, batch_idx  : 0, triplet_loss : 0.027427861467003822
# epoch : 48, globaliter : 2113, batch_idx  : 1, triplet_loss : 0.0013858284801244736
# epoch : 48, globaliter : 2114, batch_idx  : 2, triplet_loss : 0.00040257349610328674
# epoch : 48, globaliter : 2115, batch_idx  : 3, triplet_loss : 0.028177205473184586
# epoch : 48, globaliter : 2116, batch_idx  : 4, triplet_loss : 0.0
# epoch : 48, globaliter : 2117, batch_idx  : 5, triplet_loss : 0.0016394982812926173
# epoch : 48, globaliter : 2118, batch_idx  : 6, triplet_loss : 0.0028406500350683928
# epoch : 48, globaliter : 2119, batch_idx  : 7, triplet_loss : 0.001008185907267034
# epoch : 48, globaliter : 2120, batch_idx  : 8, triplet_loss : 0.0
# epoch : 48, globaliter : 2121, batch_idx  : 9, triplet_loss : 0.053324948996305466
# epoch : 48, globaliter : 2122, batch_idx  : 10, triplet_loss : 0.06696078926324844
# epoch : 48, globaliter : 2123, batch_idx  : 11, triplet_loss : 0.0009382058633491397
# epoch : 48, globaliter : 2124, batch_idx  : 12, triplet_loss : 0.0006446788902394474
# epoch : 48, globaliter : 2125, batch_idx  : 13, triplet_loss : 0.03952890262007713
# epoch : 48, globaliter : 2126, batch_idx  : 14, triplet_loss : 0.004441952332854271
# epoch : 48, globaliter : 2127, batch_idx  : 15, triplet_loss : 0.0
# epoch : 48, globaliter : 2128, batch_idx  : 16, triplet_loss : 0.013028092682361603
# epoch : 48, globaliter : 2129, batch_idx  : 17, triplet_loss : 0.003931850660592318
# epoch : 48, globaliter : 2130, batch_idx  : 18, triplet_loss : 0.00025995573378168046
# epoch : 48, globaliter : 2131, batch_idx  : 19, triplet_loss : 0.0
# epoch : 48, globaliter : 2132, batch_idx  : 20, triplet_loss : 0.0004048328846693039
# epoch : 48, globaliter : 2133, batch_idx  : 21, triplet_loss : 0.0
# epoch : 48, globaliter : 2134, batch_idx  : 22, triplet_loss : 0.0
# epoch : 48, globaliter : 2135, batch_idx  : 23, triplet_loss : 0.002215868793427944
# epoch : 48, globaliter : 2136, batch_idx  : 24, triplet_loss : 0.0158450398594141
# epoch : 48, globaliter : 2137, batch_idx  : 25, triplet_loss : 0.0
# epoch : 48, globaliter : 2138, batch_idx  : 26, triplet_loss : 0.007121174596250057
# epoch : 48, globaliter : 2139, batch_idx  : 27, triplet_loss : 0.0011424757540225983
# epoch : 48, globaliter : 2140, batch_idx  : 28, triplet_loss : 0.001692769001238048
# epoch : 48, globaliter : 2141, batch_idx  : 29, triplet_loss : 0.027884747833013535
# epoch : 48, globaliter : 2142, batch_idx  : 30, triplet_loss : 0.014347609132528305
# epoch : 48, globaliter : 2143, batch_idx  : 31, triplet_loss : 0.0
# epoch : 48, globaliter : 2144, batch_idx  : 32, triplet_loss : 0.0
# epoch : 48, globaliter : 2145, batch_idx  : 33, triplet_loss : 0.013784429989755154
# epoch : 48, globaliter : 2146, batch_idx  : 34, triplet_loss : 0.02795317769050598
# epoch : 48, globaliter : 2147, batch_idx  : 35, triplet_loss : 0.03820428624749184
# epoch : 48, globaliter : 2148, batch_idx  : 36, triplet_loss : 0.0046234712935984135
# epoch : 48, globaliter : 2149, batch_idx  : 37, triplet_loss : 0.01653013937175274
# epoch : 48, globaliter : 2150, batch_idx  : 38, triplet_loss : 0.0010670563206076622
# epoch : 48, globaliter : 2151, batch_idx  : 39, triplet_loss : 0.0038803929928690195
# epoch : 48, globaliter : 2152, batch_idx  : 40, triplet_loss : 0.020111389458179474
# epoch : 48, globaliter : 2153, batch_idx  : 41, triplet_loss : 0.06171039119362831
# epoch : 48, globaliter : 2154, batch_idx  : 42, triplet_loss : 0.02084510587155819
# epoch : 48, globaliter : 2155, batch_idx  : 43, triplet_loss : 0.0
# epoch : 49, globaliter : 2156, batch_idx  : 0, triplet_loss : 0.08250201493501663
# epoch : 49, globaliter : 2157, batch_idx  : 1, triplet_loss : 0.014868870377540588
# epoch : 49, globaliter : 2158, batch_idx  : 2, triplet_loss : 0.0
# epoch : 49, globaliter : 2159, batch_idx  : 3, triplet_loss : 0.0
# epoch : 49, globaliter : 2160, batch_idx  : 4, triplet_loss : 0.0012039244174957275
# epoch : 49, globaliter : 2161, batch_idx  : 5, triplet_loss : 0.00904612522572279
# epoch : 49, globaliter : 2162, batch_idx  : 6, triplet_loss : 0.016122492030262947
# epoch : 49, globaliter : 2163, batch_idx  : 7, triplet_loss : 0.005905697122216225
# epoch : 49, globaliter : 2164, batch_idx  : 8, triplet_loss : 0.03961736708879471
# epoch : 49, globaliter : 2165, batch_idx  : 9, triplet_loss : 0.0
# epoch : 49, globaliter : 2166, batch_idx  : 10, triplet_loss : 0.0009696539491415024
# epoch : 49, globaliter : 2167, batch_idx  : 11, triplet_loss : 0.004300170578062534
# epoch : 49, globaliter : 2168, batch_idx  : 12, triplet_loss : 0.011456935666501522
# epoch : 49, globaliter : 2169, batch_idx  : 13, triplet_loss : 0.0009066549246199429
# epoch : 49, globaliter : 2170, batch_idx  : 14, triplet_loss : 0.0010902252979576588
# epoch : 49, globaliter : 2171, batch_idx  : 15, triplet_loss : 0.015589709393680096
# epoch : 49, globaliter : 2172, batch_idx  : 16, triplet_loss : 0.013333291746675968
# epoch : 49, globaliter : 2173, batch_idx  : 17, triplet_loss : 0.0
# epoch : 49, globaliter : 2174, batch_idx  : 18, triplet_loss : 0.033881429582834244
# epoch : 49, globaliter : 2175, batch_idx  : 19, triplet_loss : 0.0024750172160565853
# epoch : 49, globaliter : 2176, batch_idx  : 20, triplet_loss : 0.0
# epoch : 49, globaliter : 2177, batch_idx  : 21, triplet_loss : 0.00925121083855629
# epoch : 49, globaliter : 2178, batch_idx  : 22, triplet_loss : 0.03897855058312416
# epoch : 49, globaliter : 2179, batch_idx  : 23, triplet_loss : 0.0
# epoch : 49, globaliter : 2180, batch_idx  : 24, triplet_loss : 0.0037425735499709845
# epoch : 49, globaliter : 2181, batch_idx  : 25, triplet_loss : 0.0017515054205432534
# epoch : 49, globaliter : 2182, batch_idx  : 26, triplet_loss : 0.021352259442210197
# epoch : 49, globaliter : 2183, batch_idx  : 27, triplet_loss : 0.0027039088308811188
# epoch : 49, globaliter : 2184, batch_idx  : 28, triplet_loss : 0.0290218535810709
# epoch : 49, globaliter : 2185, batch_idx  : 29, triplet_loss : 0.004815090447664261
# epoch : 49, globaliter : 2186, batch_idx  : 30, triplet_loss : 0.03780021890997887
# epoch : 49, globaliter : 2187, batch_idx  : 31, triplet_loss : 0.0
# epoch : 49, globaliter : 2188, batch_idx  : 32, triplet_loss : 0.0020198486745357513
# epoch : 49, globaliter : 2189, batch_idx  : 33, triplet_loss : 0.0
# epoch : 49, globaliter : 2190, batch_idx  : 34, triplet_loss : 0.0
# epoch : 49, globaliter : 2191, batch_idx  : 35, triplet_loss : 0.0
# epoch : 49, globaliter : 2192, batch_idx  : 36, triplet_loss : 0.0006478254799731076
# epoch : 49, globaliter : 2193, batch_idx  : 37, triplet_loss : 0.00014212727546691895
# epoch : 49, globaliter : 2194, batch_idx  : 38, triplet_loss : 0.0
# epoch : 49, globaliter : 2195, batch_idx  : 39, triplet_loss : 0.0
# epoch : 49, globaliter : 2196, batch_idx  : 40, triplet_loss : 0.0
# epoch : 49, globaliter : 2197, batch_idx  : 41, triplet_loss : 0.018063295632600784
# epoch : 49, globaliter : 2198, batch_idx  : 42, triplet_loss : 0.0
# epoch : 49, globaliter : 2199, batch_idx  : 43, triplet_loss : 0.0

# %%
# !wget -O model_47.pt "https://www.dropbox.com/s/g5nwt0do351huc2/model_47.pt?dl=1"
# !wget -O model_48.pt "https://www.dropbox.com/s/86qev1vgg545ee4/model_48.pt?dl=1"
# !wget -O model_49.pt "https://www.dropbox.com/s/obceyvw3d40rsxo/model_49.pt?dl=1"
# Out:
# --2022-01-13 15:37:55--  https://www.dropbox.com/s/g5nwt0do351huc2/model_47.pt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/g5nwt0do351huc2/model_47.pt [following]
# --2022-01-13 15:37:57--  https://www.dropbox.com/s/dl/g5nwt0do351huc2/model_47.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com/cd/0/get/BdvbUkmdxu9RlgTNyVcuFqbhK5J58zmFvWJeJJCv1XZO7BagRtndYuytVMgY9uzYCTu4taMISxcKVxRkOEX0xsGPI2C3MHBS4ZaleP1TafJP1GNe3xbcSwDaa5YnAfIEaHXbE9Y6DLD-jlC5vhj1Ge8L/file?dl=1# [following]
# --2022-01-13 15:37:57--  https://uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com/cd/0/get/BdvbUkmdxu9RlgTNyVcuFqbhK5J58zmFvWJeJJCv1XZO7BagRtndYuytVMgY9uzYCTu4taMISxcKVxRkOEX0xsGPI2C3MHBS4ZaleP1TafJP1GNe3xbcSwDaa5YnAfIEaHXbE9Y6DLD-jlC5vhj1Ge8L/file?dl=1
# Resolving uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com (uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com (uc25ce29056bb5528eb118d3ceee.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44791031 (43M) [application/binary]
# Saving to: ‘model_47.pt’
#
# model_47.pt         100%[===================>]  42,72M  7,09MB/s    in 5,9s
#
# 2022-01-13 15:38:04 (7,24 MB/s) - ‘model_47.pt’ saved [44791031/44791031]
#
# --2022-01-13 15:38:05--  https://www.dropbox.com/s/86qev1vgg545ee4/model_48.pt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/86qev1vgg545ee4/model_48.pt [following]
# --2022-01-13 15:38:05--  https://www.dropbox.com/s/dl/86qev1vgg545ee4/model_48.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com/cd/0/get/BduK9x4EVEXojWlopIeOKA_IhVunvP9YBdkEzOhgtODMoXfJsk2JKki7NBNDsHSACyjCaDq3bzWXaBAsl4B_GXTmuWyqswmVjCBVilXHYjZHnhfYD39xJZAKoQI5AhF8J1RHmvgGm4IdNl1Xo6YFZW_G/file?dl=1# [following]
# --2022-01-13 15:38:06--  https://uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com/cd/0/get/BduK9x4EVEXojWlopIeOKA_IhVunvP9YBdkEzOhgtODMoXfJsk2JKki7NBNDsHSACyjCaDq3bzWXaBAsl4B_GXTmuWyqswmVjCBVilXHYjZHnhfYD39xJZAKoQI5AhF8J1RHmvgGm4IdNl1Xo6YFZW_G/file?dl=1
# Resolving uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com (uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com (uc9d85b7140d28f5dce50e137557.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44791031 (43M) [application/binary]
# Saving to: ‘model_48.pt’
#
# model_48.pt         100%[===================>]  42,72M  8,38MB/s    in 5,5s
#
# 2022-01-13 15:38:12 (7,78 MB/s) - ‘model_48.pt’ saved [44791031/44791031]
#
# --2022-01-13 15:38:13--  https://www.dropbox.com/s/obceyvw3d40rsxo/model_49.pt?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/obceyvw3d40rsxo/model_49.pt [following]
# --2022-01-13 15:38:13--  https://www.dropbox.com/s/dl/obceyvw3d40rsxo/model_49.pt
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com/cd/0/get/BdscPhRsygA28apVR9Td-20_aKCdydax4ypeP1kuLLCEHR1T2w1Jg44Z0-s7CQS4t2wBfEHKhpAgx2nNihb3Dwp2Z98Ob_awC10He_vECX9jthOxYvqTKcyz4oGWys9atyEHv2w62HxRknlYv4Bx_--7/file?dl=1# [following]
# --2022-01-13 15:38:14--  https://uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com/cd/0/get/BdscPhRsygA28apVR9Td-20_aKCdydax4ypeP1kuLLCEHR1T2w1Jg44Z0-s7CQS4t2wBfEHKhpAgx2nNihb3Dwp2Z98Ob_awC10He_vECX9jthOxYvqTKcyz4oGWys9atyEHv2w62HxRknlYv4Bx_--7/file?dl=1
# Resolving uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com (uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com (uc9ea44320c2fbf089311368910d.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 44791031 (43M) [application/binary]
# Saving to: ‘model_49.pt’
#
# model_49.pt         100%[===================>]  42,72M  7,18MB/s    in 6,0s
#
# 2022-01-13 15:38:21 (7,17 MB/s) - ‘model_49.pt’ saved [44791031/44791031]

# %%
state_dict = torch.load('/home/jun/Data/F4-E5/models/model_46.pt')
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
out_train_image = model(bef_train_image.cuda())
X_train = out_train_image
Y_train = bef_train_label

# %%
for test_image,test_label in test_data_loader :  
  output_test = model(test_image.cuda())
  X_test = output_test
  Y_test = test_label

# %%
from PIL import Image
from sklearn import (manifold, datasets, decomposition, ensemble,
                     discriminant_analysis, random_projection)
import torchvision.transforms.functional as Function
from IPython.display import display
from time import time
from matplotlib import offsetbox
from sklearn.neighbors import DistanceMetric
# %matplotlib inline

def plot_embedding(X, y_t, title=None):

    y = y_t.numpy()
    
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)

    plt.figure()
    for i in range(X.shape[0]):
      if i == 776 :
        plt.text(X[i, 0], X[i, 1], str(y[i]),
               color='black',
               fontdict={'weight': 'bold', 'size': 30})
      else :
        plt.text(X[i, 0], X[i, 1], str(y[i]),
                 color=plt.cm.Set1(y[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})

    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)

# %%
check_index = 10

# %%
test_image.shape
test_label.shape
# Out:
# torch.Size([98])

# %%
image_query = X_test[check_index].view(1,-1)
label_query = Y_test[check_index].view(1)
X_total= torch.cat([X_train, image_query], dim=0)
Y_total= torch.cat([Y_train, label_query], dim=0)

test_img = Function.to_pil_image(test_image[check_index])
print('Test image : {}'.format(test_label[check_index].item()))
display(test_img)
# Out:
# Test image : 0
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FD9557FF5E0>

# %%
tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
X_tsne = tsne.fit_transform(X_total.cpu().detach().numpy())

pairwise_dist_t = _pairwise_distance(X_total)
pairwise_dist_n = pairwise_dist_t.cpu().detach().numpy()

pairwise_dist_sort = np.sort(pairwise_dist_n[-1][:-1])

# %%
test_img = Function.to_pil_image(test_image[check_index])
print('Query image : {}\n'.format(test_label[check_index].item()))
display(test_img)
print("\n")

for ii in range(5):
  idx = np.where( pairwise_dist_n[-1] == pairwise_dist_sort[ii])
  print('{} second similar {} second image : '.format(ii+1,idx[0][0]))
  img = Function.to_pil_image(bef_train_image[idx[0][0]])
  #     img.save('test{}_{}.png'.format(Y_total[ii],ii))
  display(img)
  print("\n")
# Out:
# Query image : 0
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FD95669C190>
# 1 second similar 142 second image :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FD95E110D90>
# 2 second similar 48 second image :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FD95618C640>
# 3 second similar 47 second image :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FD9557E9E80>
# 4 second similar 143 second image :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FD95618C640>
# 5 second similar 131 second image :
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FD956941F40>

# %%
plot_embedding(X_tsne, Y_total,"Sejong Landmark data set")
plt.show()

# %%
X_tsne.shape
# Out:
# (777, 2)
